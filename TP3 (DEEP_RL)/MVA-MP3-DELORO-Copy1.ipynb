# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo.io
import cv2
import json

from keras.models import Sequential,model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization

from keras.optimizers import Adam
from keras.layers.core import Flatten

from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning
#
# ### Student : Yonatan DELORO
# ### Contact : yonatan.deloro@eleves.enpc.fr
#
# ##### Presentation note : In this practical, you will find first my text answer to a given question, and just below the experiments showing the evidence (I find it clearer to present like that.).

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# [Note : I assumed there was a small typo in the indices here, and rewrote :
#
# \begin{equation*}p^{\pi}(a_{0},s_{1},a_{1},s_{2},...,s_{T-1},a_{T-1},s_{T})= \prod_{t=0}^{T-1}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# where $s_0$ denotes the initial state.]
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else:
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# > - At train time (train = True) : With a probability $\epsilon$, the agent chooses an action uniformly at random (exploration of the environment). Otherwise (with a probability $1-\epsilon$) it chooses the action maximizing the expected cumulative reward from his current state $s$, ie. the action $a$ such that the Q-value of the pair $(s,a)$ is maximal (exploitation of the currently learnt policy).
#
# > - At test time  (train = False) : The agent follows the learnt policy, ie. chooses the action maximizing the expected cumulative reward from his current state $s$, ie. the action $a$ such that the Q-value of the pair $(s,a)$ is maximal (only exploitation).
#
# > - $\epsilon$ is essential as it **tradeoffs between exploration of the environment and exploitation of the learnt policy throughout the agent training**. Indeed, if the agent only exploited ($\epsilon=1$), it would obviously never access to some potentially more interesting states than the currently exploited ones, as it would never update the Q-values of some pairs (state, action). At the opposite, if the the agent only explored ($\epsilon=0$), the agent would probably need an enormous amount of time to assess any pair (state,action) especially if positive rewards are delayed (several moves are needed to reach a positive reward) : thus the agent would learn very slowly, and even worse if the game is over at the end of short horizon. A current practice, we will implement in Q10, is to begin with a high $\epsilon$ and to decrease it throughout the training (we want to favor exploitation over exploration as the agent learns in the environment).

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        # board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0 #fixed typo
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1  #fixed typo

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x -1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x +1
            else:
                self.x = self.x - 1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]
        
        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1
        
        self.board[self.x,self.y] = 0
        self.board[self.position < 0] = 0 #I added this line  (cf. justification below)
        
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature= 0.3 
epochs_train=150 # set small when debugging
epochs_test=30  # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# > - The array position gives to the rat the information of where it can go among the cells it sees (0 if the cell is accessible, -1 if not (boundary), and 1 if the rat is already in the cell).
#
# > - The array board gives to the rat the rewards present in each cell he can see (value of 0.5 if there is a cheese in the cell, of -1 if it is a poison, 0 if there is nothing).
#
# > Note : I modified two things in the code : first, i added the border at the right of the board (missing) ; secondly, i removed any cheese/poison in the boundary areas.

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        return np.random.randint(0, self.n_action)

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix='',return_trajectories=False):
    
    if return_trajectories:
        trajectories = []
        
    score = 0
        
    for e in range(epochs):
                
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will end
        game_over = False

        win = 0
        lose = 0

        while not game_over:
                        
            # The agent performs an action
            action = agent.act(state, train=False)
            
            # Apply an action to the environment, get the next state, the reward
            prev_state = state
            state, reward, game_over = env.act(action)
            
            if return_trajectories:
                trajectories.append((prev_state,action))

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose - reward
        
        # Save as a mp4 
        if e<3:  #we will save only a few samples
            env.draw(prefix+str(e+1))

        # Update stats
        score_episode = win-lose 
        score += score_episode

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))
    
    if return_trajectories:
        return trajectories

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random1.mp4'))
# Out:
# Win/lose count 10.0/13.0. Average score (-3.0)
# Win/lose count 10.0/12.0. Average score (-2.5)
# Win/lose count 10.5/11.0. Average score (-1.8333333333333333)
# Win/lose count 15.0/15.0. Average score (-1.375)
# Win/lose count 5.5/18.0. Average score (-3.6)
# Win/lose count 6.5/15.0. Average score (-4.416666666666667)
# Win/lose count 16.5/15.0. Average score (-3.5714285714285716)
# Win/lose count 9.5/12.0. Average score (-3.4375)
# Win/lose count 6.0/10.0. Average score (-3.5)
# Win/lose count 8.5/22.0. Average score (-4.5)
# Win/lose count 8.0/13.0. Average score (-4.545454545454546)
# Win/lose count 12.0/27.0. Average score (-5.416666666666667)
# Win/lose count 6.5/22.0. Average score (-6.1923076923076925)
# Win/lose count 17.5/12.0. Average score (-5.357142857142857)
# Win/lose count 7.5/16.0. Average score (-5.566666666666666)
# Win/lose count 9.5/18.0. Average score (-5.75)
# Win/lose count 4.0/12.0. Average score (-5.882352941176471)
# Win/lose count 5.5/16.0. Average score (-6.138888888888889)
# Win/lose count 14.0/22.0. Average score (-6.2368421052631575)
# Win/lose count 11.5/14.0. Average score (-6.05)
# Win/lose count 12.5/19.0. Average score (-6.071428571428571)
# Win/lose count 7.0/19.0. Average score (-6.340909090909091)
# Win/lose count 8.0/7.0. Average score (-6.021739130434782)
# Win/lose count 8.0/21.0. Average score (-6.3125)
# Win/lose count 9.5/9.0. Average score (-6.04)
# Win/lose count 9.0/9.0. Average score (-5.8076923076923075)
# Win/lose count 12.0/21.0. Average score (-5.925925925925926)
# Win/lose count 11.0/11.0. Average score (-5.714285714285714)
# Win/lose count 5.5/11.0. Average score (-5.706896551724138)
# Win/lose count 10.0/6.0. Average score (-5.383333333333334)
# Final score: -5.383333333333334
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# > **My answer** :
#
# > I assumed there were small typos in the assertions to prove. Let us rewrite the question first :
#
# > 1. Let $\pi$ be a policy, show that: \begin{equation*}
# Q^{\pi}(s,a)=E_{s'\sim p(.|s,a), ~a' \sim \pi(.|s')}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# > 2. Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:  \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim p(.|s,a)}[r(s,a)+\gamma \max_{a'} Q^{*}(s',a')]
# \end{equation*}
#
# > 3. Finally, deduce that a plausible objective is:
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim p(.|s,a)}\Vert r(s,a) +\gamma \max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}
# \end{equation*}
#
#
# ***
#
# > **Question 1**
#
# > $Q^{\pi}(s,a)$ is defined as the expected cumulative reward over trajectories beginning in state $s$ with action $a$ and following policy $\pi$. We can rewrite it as :
#
#
# > \begin{align} Q^\pi(s,a) &=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a]
# \\ &= r(s, a) + \gamma E_{p^{\pi}}[\sum_{1 \leq t \leq T} \gamma^{t - 1} r(s_t,a_t)|s_0=s,a_0=a]
# \\ &= r(s, a) + \gamma \sum_{s'} \mathbb{P}(s_1 = s' | s_0 = s,a_0=a) \sum_{a'} \pi(a'|s') E_{p^{\pi}}[\sum_{1 \leq t \leq T} \gamma^{t - 1} r(s_t,a_t)|s_1=s',a_1=a']
# \\ &= r(s, a) + \gamma \sum_{s'}  p(s'|s,a)  \sum_{a'} \pi(a'|s') E_{p^{\pi}}[\sum_{0 \leq t \leq T-1} \gamma^{t} r(s_t,a_t)|s_0=s',a_0=a'] \\
#  & = r(s,a) + \gamma \sum_{s'} p(s'|s,a) \sum_{a'} \pi(a'|s')  Q^{\pi}(s',a')\end{align}
#
#
# > This is the so-called Bellman equation (which tells that the expected discounted cumulative reward in state $s$ taking action $a$ is the sum of the immediate reward $r(s,a)$ and of the expectation of the discounted cumulative reward over all new reachable state $s' \sim p(.|s,a)$ and taking action from state $s'$ following the policy $\pi$ (ie. choosing $a' \sim \pi(.|s')$)).
#
# > Then, $$\begin{align}
# Q^{\pi}(s,a)& = r(s,a) + \gamma \sum_{s'} p(s'|s,a) \sum_{a'} \pi(a'|s')  Q^{\pi}(s',a') \\
# &= \sum_{s'} p(s'|s,a) \left( r(s,a) + \gamma \sum_{a'} \pi(a'|s')  Q^{\pi}(s',a')\right) \\
# &= \sum_{s'} p(s'|s,a) \sum_{a'} \pi(a'|s')  \left( r(s,a) + \gamma Q^{\pi}(s',a') \right) \\
# &=E_{s'\sim p(.|s,a), ~a' \sim \pi(.|s')}[r(s,a)+\gamma Q^{\pi}(s',a')].
# \end{align}$$
#
#
# ***
#
# > **Question 2**
#
#
# > Denoting $Q^{*} = Q^{\pi^*}$ the state-action value function associated to the optimal policy,
#
# $$\begin{align}
# Q^{*}(s,a) &= E_{s'\sim p(.|s,a), ~a' \sim \pi(.|s')}[r(s,a)+\gamma Q^{*}(s',a')] \\
# &=E_{s'\sim p(.|s,a)}   \left[ r(s,a) + \gamma  \sum_{a'} \pi(a'|s') Q^{*}(s',a') \right].
# \end{align}$$
#
#
# > But the optimal policy $\pi^*$ satisfies for any action $a$ : $$\pi^*(a|s) = 1_{a = a_0} $$ where we set : $$a_0 = \arg \max_{a} Q^{*}(s,a)$$
#
# > Hence : $$\begin{align}
# Q^{*}(s,a) &= E_{s'\sim p(.|s,a)} \left[ r(s,a)+\gamma Q^{*} \left( s',\arg \max_{a'} Q^{*}(s',a') \right) \right] \\
# &=E_{s'\sim p(.|s,a)}[r(s,a)+\gamma \max_{a'} Q^{*}(s',a')] \end{align}$$
#
# ***
#
# > **Question 3**
#
# > Hence :  $$ E_{s'\sim p(.|s,a)}[r(s,a)+\gamma \max_{a'} Q^{*}(s',a')- Q^{*}(s,a) ] = 0 $$
#
# > Therefore, such matrix $Q^{*}$ will minimize the following loss : \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim p(.|s,a)}\Vert r(s,a) +\gamma \max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# [Note : I assumed that at state $s_t$, we select the action $a_t$ following an epsilon-greedy policy (ie. the one with highest $Q_t$ value with probability 1-epsilon, and uniformly at random otherwise]
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        self.memory.append(m)
        if len(self.memory)>self.max_memory:
            self.memory = self.memory[-self.max_memory:]

    def random_access(self):
        idx = np.random.randint(len(self.memory))
        return self.memory[idx]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    
    history_losses = []
    history_scores = []    
    
    score = 0
    
    for e in range(epoch):
            
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False
        
        loss = 0

        win = 0
        lose = 0
        
        t = 0

        while not game_over:
            
            # The agent performs an action
            action = agent.act(state, train=True)

            # Apply an action to the environment, get the next state, the reward
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose - reward

            # Apply the reinforcement strategy
            loss += agent.reinforce(prev_state, state,  action, reward, game_over)
            
            t+=1
            
        loss /= t
            
        history_losses.append(loss)

        # Save as a mp4
        if (e+1) % 50 == 0:
            env.draw(prefix+str(e+1))

        # Update stats
        score_episode = win-lose
        score += score_episode
        history_scores.append(score_episode)

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, score_episode))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
    return history_losses, history_scores

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %% [markdown]
# > Though I tried several depths and widths for the fully connected network, the one which gave me the best outcomes was composed of only one hidden layer with 32 neurons, followed by relu activations. A higher number of hidden layers seemed to lead to overfitting, to which the dropout layer I previously used did not really manage to face.  I used a learning rate of 0.1, a memory of size 2000, and a batch size of 32.
#
# > As mentionned in the question, the mean loss per episode oscillates throughout the training whenever the rat start to eat more cheese than poison, but the score per episode keeps increasing despite these oscillations. This is not completely unexpected : indeed, as the rat plays better, it gets positive rewards and it may encounter more difficult situations (with less cheese directly around him) and thus face harder estimations of Q-values. In addition, we are using the same network to estimate the Q target and the Q-value, thus we are getting closer to a target which is itself moving, hence leading to the loss oscillations.
#
# > Given that the loss oscillations do not translate into a plateau/decrease of performances, I did not choose a  training stopping criteria based on the loss evolution, but chose to fix a large number of epochs (chosen empirically looking at the score evolution throughout training, cf. below). I prefered this simple strategy to a criterium upon the score evolution, as this oscillated too in practice.

# %%
class DQN(Agent):
    def __init__(self, grid_size = 10.,  epsilon = 0.1, memory_size=100, batch_size = 16, n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        state_action_values = self.model.predict(s[None,:,:,:]).flatten()
        return np.argmax(state_action_values)

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5, 5, self.n_state))
        
        steps = [self.memory.random_access() for i in range(self.batch_size)]
        
        #storing init states
        input_states = np.array([s[0] for s in steps])
        
        #storing next_states, played actions, rewards, and booleans game_over 
        next_state = np.array([s[1] for s in steps])
        tmp = np.array([s[2:] for s in steps])
        played_action = tmp[:,0].astype(int)
        reward = tmp[:,1]
        game_over = tmp[:,2]
        
        #computing current assessments of q(init_state,action) for any action from init_state
        target_q = self.model.predict(input_states)
        
        #reassessing q(input_state,action) for the played action from input_state
        q_next_state = self.model.predict(next_state) #q-values in next state of all actions
        target_q_played_action = reward  + (1-game_over) * self.discount * np.max(q_next_state,axis=1) 
        for i in range(self.batch_size):
            target_q[i, played_action[i]] = target_q_played_action[i]
        
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter        
        target_q = np.clip(target_q, -3, 3)

        #early_stopping_monitor = EarlyStopping(patience = 5)
        l = self.model.train_on_batch(input_states, target_q)

        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        
        model.compile("sgd", "mse")
        
        self.model = model


class DQN_FC(DQN):
    def __init__(self, lr=0.1, *args, **kwargs):
        super(DQN_FC, self).__init__(*args,**kwargs)
        
        # NN Model
        
        model = Sequential()
        model.add(Flatten(input_shape = (5,5,self.n_state,)))
        model.add(Dense(32))
        model.add(Activation('relu'))
        model.add(Dense(16))
        model.add(Activation('relu'))
        model.add(Dense(self.n_action))
        
        model.summary()
        
        opt = sgd(lr=lr, decay=1e-4, momentum=0.0)
        model.compile(loss="mse", optimizer = opt)
        
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=temperature)
agent_dqn_fc = DQN_FC(grid_size=size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
history_losses_dqn_fc, history_scores_dqn_fc = train(agent_dqn_fc, env, epochs_train, prefix='fc_train')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1632
# _________________________________________________________________
# activation_1 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                528
# _________________________________________________________________
# activation_2 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 2,228
# Trainable params: 2,228
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/150 | Loss 0.0280 | Win/lose count 3.0/1.0 (2.0)
# Epoch 001/150 | Loss 0.0121 | Win/lose count 2.5/1.0 (1.5)
# Epoch 002/150 | Loss 0.0136 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 003/150 | Loss 0.0164 | Win/lose count 4.5/7.0 (-2.5)
# Epoch 004/150 | Loss 0.0163 | Win/lose count 4.0/4.0 (0.0)
# Epoch 005/150 | Loss 0.0159 | Win/lose count 5.0/3.0 (2.0)
# Epoch 006/150 | Loss 0.0150 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 007/150 | Loss 0.0144 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 008/150 | Loss 0.0139 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 009/150 | Loss 0.0119 | Win/lose count 4.5/1.0 (3.5)
# Epoch 010/150 | Loss 0.0129 | Win/lose count 2.0/1.0 (1.0)
# Epoch 011/150 | Loss 0.0113 | Win/lose count 3.0/1.0 (2.0)
# Epoch 012/150 | Loss 0.0147 | Win/lose count 2.0/5.0 (-3.0)
# Epoch 013/150 | Loss 0.0126 | Win/lose count 2.0/2.0 (0.0)
# Epoch 014/150 | Loss 0.0118 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 015/150 | Loss 0.0118 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 016/150 | Loss 0.0130 | Win/lose count 3.0/3.0 (0.0)
# Epoch 017/150 | Loss 0.0132 | Win/lose count 3.0/2.0 (1.0)
# Epoch 018/150 | Loss 0.0121 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 019/150 | Loss 0.0126 | Win/lose count 2.5/1.0 (1.5)
# Epoch 020/150 | Loss 0.0114 | Win/lose count 5.0/0 (5.0)
# Epoch 021/150 | Loss 0.0098 | Win/lose count 5.0/5.0 (0.0)
# Epoch 022/150 | Loss 0.0096 | Win/lose count 2.5/1.0 (1.5)
# Epoch 023/150 | Loss 0.0122 | Win/lose count 5.5/1.0 (4.5)
# Epoch 024/150 | Loss 0.0101 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 025/150 | Loss 0.0130 | Win/lose count 5.5/3.0 (2.5)
# Epoch 026/150 | Loss 0.0145 | Win/lose count 3.5/2.0 (1.5)
# Epoch 027/150 | Loss 0.0146 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 028/150 | Loss 0.0118 | Win/lose count 3.0/3.0 (0.0)
# Epoch 029/150 | Loss 0.0127 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 030/150 | Loss 0.0142 | Win/lose count 7.5/1.0 (6.5)
# Epoch 031/150 | Loss 0.0130 | Win/lose count 4.0/0 (4.0)
# Epoch 032/150 | Loss 0.0140 | Win/lose count 7.0/2.0 (5.0)
# Epoch 033/150 | Loss 0.0141 | Win/lose count 6.5/3.0 (3.5)
# Epoch 034/150 | Loss 0.0147 | Win/lose count 3.0/3.0 (0.0)
# Epoch 035/150 | Loss 0.0117 | Win/lose count 5.5/2.0 (3.5)
# Epoch 036/150 | Loss 0.0145 | Win/lose count 6.0/5.0 (1.0)
# Epoch 037/150 | Loss 0.0117 | Win/lose count 3.5/0 (3.5)
# Epoch 038/150 | Loss 0.0140 | Win/lose count 8.5/2.0 (6.5)
# Epoch 039/150 | Loss 0.0112 | Win/lose count 8.5/5.0 (3.5)
# Epoch 040/150 | Loss 0.0135 | Win/lose count 2.0/0 (2.0)
# Epoch 041/150 | Loss 0.0103 | Win/lose count 9.0/2.0 (7.0)
# Epoch 042/150 | Loss 0.0123 | Win/lose count 5.5/4.0 (1.5)
# Epoch 043/150 | Loss 0.0120 | Win/lose count 5.0/3.0 (2.0)
# Epoch 044/150 | Loss 0.0137 | Win/lose count 10.5/5.0 (5.5)
# Epoch 045/150 | Loss 0.0125 | Win/lose count 14.0/6.0 (8.0)
# Epoch 046/150 | Loss 0.0117 | Win/lose count 8.5/3.0 (5.5)
# Epoch 047/150 | Loss 0.0111 | Win/lose count 9.0/6.0 (3.0)
# Epoch 048/150 | Loss 0.0136 | Win/lose count 7.0/6.0 (1.0)
# Epoch 049/150 | Loss 0.0137 | Win/lose count 9.5/2.0 (7.5)
# Epoch 050/150 | Loss 0.0130 | Win/lose count 6.5/4.0 (2.5)
# Epoch 051/150 | Loss 0.0142 | Win/lose count 5.5/3.0 (2.5)
# Epoch 052/150 | Loss 0.0116 | Win/lose count 3.0/1.0 (2.0)
# Epoch 053/150 | Loss 0.0123 | Win/lose count 6.0/6.0 (0.0)
# Epoch 054/150 | Loss 0.0125 | Win/lose count 5.5/5.0 (0.5)
# Epoch 055/150 | Loss 0.0126 | Win/lose count 10.0/2.0 (8.0)
# Epoch 056/150 | Loss 0.0130 | Win/lose count 5.5/2.0 (3.5)
# Epoch 057/150 | Loss 0.0122 | Win/lose count 12.0/0 (12.0)
# Epoch 058/150 | Loss 0.0123 | Win/lose count 6.0/2.0 (4.0)
# Epoch 059/150 | Loss 0.0115 | Win/lose count 3.5/0 (3.5)
# Epoch 060/150 | Loss 0.0143 | Win/lose count 10.0/0 (10.0)
# Epoch 061/150 | Loss 0.0138 | Win/lose count 9.0/3.0 (6.0)
# Epoch 062/150 | Loss 0.0121 | Win/lose count 5.0/0 (5.0)
# Epoch 063/150 | Loss 0.0101 | Win/lose count 7.5/2.0 (5.5)
# Epoch 064/150 | Loss 0.0108 | Win/lose count 11.0/4.0 (7.0)
# Epoch 065/150 | Loss 0.0131 | Win/lose count 2.0/1.0 (1.0)
# Epoch 066/150 | Loss 0.0114 | Win/lose count 9.0/5.0 (4.0)
# Epoch 067/150 | Loss 0.0128 | Win/lose count 9.0/2.0 (7.0)
# Epoch 068/150 | Loss 0.0138 | Win/lose count 6.0/3.0 (3.0)
# Epoch 069/150 | Loss 0.0109 | Win/lose count 10.0/1.0 (9.0)
# Epoch 070/150 | Loss 0.0095 | Win/lose count 4.5/1.0 (3.5)
# Epoch 071/150 | Loss 0.0127 | Win/lose count 5.0/3.0 (2.0)
# Epoch 072/150 | Loss 0.0118 | Win/lose count 10.0/4.0 (6.0)
# Epoch 073/150 | Loss 0.0117 | Win/lose count 12.0/2.0 (10.0)
# Epoch 074/150 | Loss 0.0102 | Win/lose count 9.0/3.0 (6.0)
# Epoch 075/150 | Loss 0.0120 | Win/lose count 6.5/3.0 (3.5)
# Epoch 076/150 | Loss 0.0096 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 077/150 | Loss 0.0097 | Win/lose count 9.0/5.0 (4.0)
# Epoch 078/150 | Loss 0.0121 | Win/lose count 8.5/2.0 (6.5)
# Epoch 079/150 | Loss 0.0129 | Win/lose count 10.0/1.0 (9.0)
# Epoch 080/150 | Loss 0.0085 | Win/lose count 6.5/3.0 (3.5)
# Epoch 081/150 | Loss 0.0110 | Win/lose count 9.0/0 (9.0)
# Epoch 082/150 | Loss 0.0116 | Win/lose count 5.5/1.0 (4.5)
# Epoch 083/150 | Loss 0.0104 | Win/lose count 5.0/8.0 (-3.0)
# Epoch 084/150 | Loss 0.0115 | Win/lose count 7.5/1.0 (6.5)
# Epoch 085/150 | Loss 0.0111 | Win/lose count 7.5/0 (7.5)
# Epoch 086/150 | Loss 0.0099 | Win/lose count 8.5/3.0 (5.5)
# Epoch 087/150 | Loss 0.0095 | Win/lose count 12.0/2.0 (10.0)
# Epoch 088/150 | Loss 0.0106 | Win/lose count 9.5/3.0 (6.5)
# Epoch 089/150 | Loss 0.0119 | Win/lose count 10.0/2.0 (8.0)
# Epoch 090/150 | Loss 0.0127 | Win/lose count 13.0/2.0 (11.0)
# Epoch 091/150 | Loss 0.0106 | Win/lose count 7.5/2.0 (5.5)
# Epoch 092/150 | Loss 0.0107 | Win/lose count 7.5/10.0 (-2.5)
# Epoch 093/150 | Loss 0.0100 | Win/lose count 5.5/2.0 (3.5)
# Epoch 094/150 | Loss 0.0139 | Win/lose count 16.5/0 (16.5)
# Epoch 095/150 | Loss 0.0133 | Win/lose count 6.5/3.0 (3.5)
# Epoch 096/150 | Loss 0.0104 | Win/lose count 7.0/0 (7.0)
# Epoch 097/150 | Loss 0.0104 | Win/lose count 11.0/2.0 (9.0)
# Epoch 098/150 | Loss 0.0106 | Win/lose count 3.5/0 (3.5)
# Epoch 099/150 | Loss 0.0104 | Win/lose count 5.5/4.0 (1.5)
# Epoch 100/150 | Loss 0.0117 | Win/lose count 12.5/5.0 (7.5)
# Epoch 101/150 | Loss 0.0108 | Win/lose count 5.0/1.0 (4.0)
# Epoch 102/150 | Loss 0.0094 | Win/lose count 14.5/1.0 (13.5)
# Epoch 103/150 | Loss 0.0122 | Win/lose count 9.0/4.0 (5.0)
# Epoch 104/150 | Loss 0.0122 | Win/lose count 20.5/4.0 (16.5)
# Epoch 105/150 | Loss 0.0104 | Win/lose count 12.5/3.0 (9.5)
# Epoch 106/150 | Loss 0.0111 | Win/lose count 6.0/0 (6.0)
# Epoch 107/150 | Loss 0.0121 | Win/lose count 3.0/0 (3.0)
# Epoch 108/150 | Loss 0.0122 | Win/lose count 2.0/0 (2.0)
# Epoch 109/150 | Loss 0.0105 | Win/lose count 12.5/4.0 (8.5)
# Epoch 110/150 | Loss 0.0128 | Win/lose count 4.0/1.0 (3.0)
# Epoch 111/150 | Loss 0.0092 | Win/lose count 6.0/1.0 (5.0)
# Epoch 112/150 | Loss 0.0119 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 113/150 | Loss 0.0107 | Win/lose count 8.5/6.0 (2.5)
# Epoch 114/150 | Loss 0.0108 | Win/lose count 5.5/3.0 (2.5)
# Epoch 115/150 | Loss 0.0121 | Win/lose count 8.5/1.0 (7.5)
# Epoch 116/150 | Loss 0.0083 | Win/lose count 9.0/4.0 (5.0)
# Epoch 117/150 | Loss 0.0093 | Win/lose count 16.5/4.0 (12.5)
# Epoch 118/150 | Loss 0.0116 | Win/lose count 9.5/1.0 (8.5)
# Epoch 119/150 | Loss 0.0108 | Win/lose count 8.5/3.0 (5.5)
# Epoch 120/150 | Loss 0.0100 | Win/lose count 10.0/6.0 (4.0)
# Epoch 121/150 | Loss 0.0099 | Win/lose count 8.5/0 (8.5)
# Epoch 122/150 | Loss 0.0112 | Win/lose count 8.0/0 (8.0)
# Epoch 123/150 | Loss 0.0102 | Win/lose count 7.0/2.0 (5.0)
# Epoch 124/150 | Loss 0.0107 | Win/lose count 21.5/1.0 (20.5)
# Epoch 125/150 | Loss 0.0098 | Win/lose count 19.0/1.0 (18.0)
# Epoch 126/150 | Loss 0.0123 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 127/150 | Loss 0.0118 | Win/lose count 10.0/1.0 (9.0)
# Epoch 128/150 | Loss 0.0118 | Win/lose count 5.0/1.0 (4.0)
# Epoch 129/150 | Loss 0.0115 | Win/lose count 18.0/6.0 (12.0)
# Epoch 130/150 | Loss 0.0117 | Win/lose count 8.5/4.0 (4.5)
# Epoch 131/150 | Loss 0.0115 | Win/lose count 19.5/1.0 (18.5)
# Epoch 132/150 | Loss 0.0147 | Win/lose count 16.0/5.0 (11.0)
# Epoch 133/150 | Loss 0.0104 | Win/lose count 14.0/1.0 (13.0)
# Epoch 134/150 | Loss 0.0114 | Win/lose count 11.5/0 (11.5)
# Epoch 135/150 | Loss 0.0138 | Win/lose count 8.5/1.0 (7.5)
# Epoch 136/150 | Loss 0.0119 | Win/lose count 11.0/1.0 (10.0)
# Epoch 137/150 | Loss 0.0102 | Win/lose count 7.5/5.0 (2.5)
# Epoch 138/150 | Loss 0.0116 | Win/lose count 17.5/3.0 (14.5)
# Epoch 139/150 | Loss 0.0108 | Win/lose count 9.5/3.0 (6.5)
# Epoch 140/150 | Loss 0.0123 | Win/lose count 4.0/3.0 (1.0)
# Epoch 141/150 | Loss 0.0122 | Win/lose count 24.0/5.0 (19.0)
# Epoch 142/150 | Loss 0.0098 | Win/lose count 8.0/2.0 (6.0)
# Epoch 143/150 | Loss 0.0110 | Win/lose count 12.5/4.0 (8.5)
# Epoch 144/150 | Loss 0.0129 | Win/lose count 14.0/4.0 (10.0)
# Epoch 145/150 | Loss 0.0099 | Win/lose count 6.0/4.0 (2.0)
# Epoch 146/150 | Loss 0.0139 | Win/lose count 17.5/3.0 (14.5)
# Epoch 147/150 | Loss 0.0101 | Win/lose count 11.0/4.0 (7.0)
# Epoch 148/150 | Loss 0.0124 | Win/lose count 12.0/2.0 (10.0)
# Epoch 149/150 | Loss 0.0082 | Win/lose count 6.0/1.0 (5.0)

# %%
HTML(display_videos('fc_train150.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
plt.plot(history_losses_dqn_fc,marker="+",color="b")
plt.xlabel("episodes") ; plt.ylabel("average training loss across episod") 
plt.show()

plt.plot(history_scores_dqn_fc,marker="+",color="r")
plt.xlabel("episodes") ; plt.ylabel("score at episod (win-lose)") 
plt.show()

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %% [markdown]
# > The convolutional network which led me to the best performances is the one above, composed of 2 convolutional layers with 16 small filters of size (2,2), each followed by relu activations, and 1 final fully connected layer. This convolutional network has exactly the same number of parameters as the previous fully connected network, but as we will see, it performs much better. I observed that a larger number of filters or size of filters was detrimental to the results. In addition, pooling layers particularly decreased performances (probably they compressed too much the information).  I again used a learning rate of 0.1, a memory of size 2000, and a batch size of 32 for the training of the CNN.
#
# > With the chosen CNN architecture, we can observe that wile the mean loss per episode oscillates throughout the training, the score per episode keeps increasing. This is not completely unexpected : indeed, as the rat plays better, it may encounter more difficult situations (with less cheese directly around him) and thus has to estimate more tricky Q-values. In addition, we are using the same network to estimate the Q target and the Q-value, thus we are getting closer to a target which is itself moving, hence leading to the loss oscillations.

# %%
class DQN_CNN(DQN):
    def __init__(self, lr=0.1, *args, **kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
                
        model = Sequential() 
    
        model.add(Conv2D(16, (3, 3), activation='relu', input_shape=(5,5,self.n_state,)))
        model.add(Conv2D(16, (3, 3), activation='relu'))
        model.add(Flatten())
        model.add(Dense(self.n_action))

        model.summary()
        
        opt = sgd(lr=lr, decay=1e-4, momentum=0.0)
        model.compile(loss="mse", optimizer = opt)
        
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=temperature)
agent_dqn_cnn = DQN_CNN(grid_size=size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
history_losses_dqn_cnn, history_scores_dqn_cnn = train(agent_dqn_cnn,env,epochs_train,prefix='cnn_train')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 3, 3, 16)          304
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 1, 16)          2320
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 2,692
# Trainable params: 2,692
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/150 | Loss 0.0087 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 001/150 | Loss 0.0040 | Win/lose count 0.5/2.0 (-1.5)
# Epoch 002/150 | Loss 0.0038 | Win/lose count 4.5/3.0 (1.5)
# Epoch 003/150 | Loss 0.0036 | Win/lose count 2.0/0 (2.0)
# Epoch 004/150 | Loss 0.0039 | Win/lose count 3.5/2.0 (1.5)
# Epoch 005/150 | Loss 0.0037 | Win/lose count 3.0/1.0 (2.0)
# Epoch 006/150 | Loss 0.0046 | Win/lose count 4.0/3.0 (1.0)
# Epoch 007/150 | Loss 0.0058 | Win/lose count 5.0/4.0 (1.0)
# Epoch 008/150 | Loss 0.0055 | Win/lose count 3.0/2.0 (1.0)
# Epoch 009/150 | Loss 0.0068 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 010/150 | Loss 0.0074 | Win/lose count 4.0/10.0 (-6.0)
# Epoch 011/150 | Loss 0.0099 | Win/lose count 5.0/4.0 (1.0)
# Epoch 012/150 | Loss 0.0110 | Win/lose count 1.0/4.0 (-3.0)
# Epoch 013/150 | Loss 0.0109 | Win/lose count 5.5/0 (5.5)
# Epoch 014/150 | Loss 0.0107 | Win/lose count 3.0/2.0 (1.0)
# Epoch 015/150 | Loss 0.0130 | Win/lose count 4.0/3.0 (1.0)
# Epoch 016/150 | Loss 0.0109 | Win/lose count 2.0/2.0 (0.0)
# Epoch 017/150 | Loss 0.0123 | Win/lose count 0.5/1.0 (-0.5)
# Epoch 018/150 | Loss 0.0105 | Win/lose count 4.0/7.0 (-3.0)
# Epoch 019/150 | Loss 0.0129 | Win/lose count 4.0/6.0 (-2.0)
# Epoch 020/150 | Loss 0.0114 | Win/lose count 3.0/1.0 (2.0)
# Epoch 021/150 | Loss 0.0107 | Win/lose count 4.5/2.0 (2.5)
# Epoch 022/150 | Loss 0.0101 | Win/lose count 2.5/2.0 (0.5)
# Epoch 023/150 | Loss 0.0085 | Win/lose count 4.5/1.0 (3.5)
# Epoch 024/150 | Loss 0.0094 | Win/lose count 2.5/2.0 (0.5)
# Epoch 025/150 | Loss 0.0086 | Win/lose count 8.0/4.0 (4.0)
# Epoch 026/150 | Loss 0.0097 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 027/150 | Loss 0.0110 | Win/lose count 5.0/1.0 (4.0)
# Epoch 028/150 | Loss 0.0090 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 029/150 | Loss 0.0094 | Win/lose count 4.5/2.0 (2.5)
# Epoch 030/150 | Loss 0.0117 | Win/lose count 10.5/1.0 (9.5)
# Epoch 031/150 | Loss 0.0097 | Win/lose count 5.0/4.0 (1.0)
# Epoch 032/150 | Loss 0.0099 | Win/lose count 9.0/3.0 (6.0)
# Epoch 033/150 | Loss 0.0102 | Win/lose count 14.0/5.0 (9.0)
# Epoch 034/150 | Loss 0.0118 | Win/lose count 6.0/1.0 (5.0)
# Epoch 035/150 | Loss 0.0109 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 036/150 | Loss 0.0106 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 037/150 | Loss 0.0112 | Win/lose count 9.0/0 (9.0)
# Epoch 038/150 | Loss 0.0110 | Win/lose count 10.0/6.0 (4.0)
# Epoch 039/150 | Loss 0.0111 | Win/lose count 17.0/1.0 (16.0)
# Epoch 040/150 | Loss 0.0125 | Win/lose count 15.5/3.0 (12.5)
# Epoch 041/150 | Loss 0.0121 | Win/lose count 3.5/2.0 (1.5)
# Epoch 042/150 | Loss 0.0121 | Win/lose count 5.5/2.0 (3.5)
# Epoch 043/150 | Loss 0.0118 | Win/lose count 3.5/3.0 (0.5)
# Epoch 044/150 | Loss 0.0109 | Win/lose count 11.5/1.0 (10.5)
# Epoch 045/150 | Loss 0.0128 | Win/lose count 8.5/1.0 (7.5)
# Epoch 046/150 | Loss 0.0131 | Win/lose count 6.5/2.0 (4.5)
# Epoch 047/150 | Loss 0.0103 | Win/lose count 5.5/2.0 (3.5)
# Epoch 048/150 | Loss 0.0107 | Win/lose count 8.5/3.0 (5.5)
# Epoch 049/150 | Loss 0.0098 | Win/lose count 13.5/4.0 (9.5)
# Epoch 050/150 | Loss 0.0121 | Win/lose count 9.5/1.0 (8.5)
# Epoch 051/150 | Loss 0.0094 | Win/lose count 15.0/0 (15.0)
# Epoch 052/150 | Loss 0.0124 | Win/lose count 8.0/2.0 (6.0)
# Epoch 053/150 | Loss 0.0104 | Win/lose count 5.0/0 (5.0)
# Epoch 054/150 | Loss 0.0113 | Win/lose count 14.5/3.0 (11.5)
# Epoch 055/150 | Loss 0.0102 | Win/lose count 7.0/6.0 (1.0)
# Epoch 056/150 | Loss 0.0088 | Win/lose count 15.0/3.0 (12.0)
# Epoch 057/150 | Loss 0.0098 | Win/lose count 10.5/1.0 (9.5)
# Epoch 058/150 | Loss 0.0103 | Win/lose count 7.0/2.0 (5.0)
# Epoch 059/150 | Loss 0.0104 | Win/lose count 0.5/1.0 (-0.5)
# Epoch 060/150 | Loss 0.0119 | Win/lose count 2.5/1.0 (1.5)
# Epoch 061/150 | Loss 0.0110 | Win/lose count 4.0/2.0 (2.0)
# Epoch 062/150 | Loss 0.0109 | Win/lose count 17.5/0 (17.5)
# Epoch 063/150 | Loss 0.0088 | Win/lose count 6.0/1.0 (5.0)
# Epoch 064/150 | Loss 0.0081 | Win/lose count 7.0/3.0 (4.0)
# Epoch 065/150 | Loss 0.0098 | Win/lose count 13.5/4.0 (9.5)
# Epoch 066/150 | Loss 0.0112 | Win/lose count 13.5/1.0 (12.5)
# Epoch 067/150 | Loss 0.0091 | Win/lose count 19.5/4.0 (15.5)
# Epoch 068/150 | Loss 0.0110 | Win/lose count 19.0/1.0 (18.0)
# Epoch 069/150 | Loss 0.0112 | Win/lose count 26.0/7.0 (19.0)
# Epoch 070/150 | Loss 0.0093 | Win/lose count 20.0/5.0 (15.0)
# Epoch 071/150 | Loss 0.0114 | Win/lose count 12.0/4.0 (8.0)
# Epoch 072/150 | Loss 0.0089 | Win/lose count 15.5/5.0 (10.5)
# Epoch 073/150 | Loss 0.0110 | Win/lose count 11.5/4.0 (7.5)
# Epoch 074/150 | Loss 0.0118 | Win/lose count 8.0/3.0 (5.0)
# Epoch 075/150 | Loss 0.0121 | Win/lose count 11.0/3.0 (8.0)
# Epoch 076/150 | Loss 0.0119 | Win/lose count 11.5/4.0 (7.5)
# Epoch 077/150 | Loss 0.0111 | Win/lose count 14.0/2.0 (12.0)
# Epoch 078/150 | Loss 0.0095 | Win/lose count 16.0/1.0 (15.0)
# Epoch 079/150 | Loss 0.0124 | Win/lose count 11.0/3.0 (8.0)
# Epoch 080/150 | Loss 0.0121 | Win/lose count 17.0/0 (17.0)
# Epoch 081/150 | Loss 0.0098 | Win/lose count 5.0/3.0 (2.0)
# Epoch 082/150 | Loss 0.0084 | Win/lose count 10.5/3.0 (7.5)
# Epoch 083/150 | Loss 0.0109 | Win/lose count 20.0/1.0 (19.0)
# Epoch 084/150 | Loss 0.0095 | Win/lose count 16.5/3.0 (13.5)
# Epoch 085/150 | Loss 0.0107 | Win/lose count 19.0/1.0 (18.0)
# Epoch 086/150 | Loss 0.0087 | Win/lose count 21.0/3.0 (18.0)
# Epoch 087/150 | Loss 0.0106 | Win/lose count 14.5/1.0 (13.5)
# Epoch 088/150 | Loss 0.0119 | Win/lose count 19.5/3.0 (16.5)
# Epoch 089/150 | Loss 0.0113 | Win/lose count 15.0/1.0 (14.0)
# Epoch 090/150 | Loss 0.0114 | Win/lose count 10.5/2.0 (8.5)
# Epoch 091/150 | Loss 0.0110 | Win/lose count 20.0/2.0 (18.0)
# Epoch 092/150 | Loss 0.0110 | Win/lose count 8.0/1.0 (7.0)
# Epoch 093/150 | Loss 0.0089 | Win/lose count 13.5/4.0 (9.5)
# Epoch 094/150 | Loss 0.0095 | Win/lose count 24.5/2.0 (22.5)
# Epoch 095/150 | Loss 0.0093 | Win/lose count 18.5/4.0 (14.5)
# Epoch 096/150 | Loss 0.0129 | Win/lose count 7.0/1.0 (6.0)
# Epoch 097/150 | Loss 0.0087 | Win/lose count 13.5/6.0 (7.5)
# Epoch 098/150 | Loss 0.0108 | Win/lose count 19.0/3.0 (16.0)
# Epoch 099/150 | Loss 0.0111 | Win/lose count 15.0/5.0 (10.0)
# Epoch 100/150 | Loss 0.0113 | Win/lose count 19.5/4.0 (15.5)
# Epoch 101/150 | Loss 0.0122 | Win/lose count 16.5/1.0 (15.5)
# Epoch 102/150 | Loss 0.0123 | Win/lose count 14.5/3.0 (11.5)
# Epoch 103/150 | Loss 0.0095 | Win/lose count 19.0/0 (19.0)
# Epoch 104/150 | Loss 0.0112 | Win/lose count 15.5/2.0 (13.5)
# Epoch 105/150 | Loss 0.0133 | Win/lose count 19.0/7.0 (12.0)
# Epoch 106/150 | Loss 0.0118 | Win/lose count 17.0/3.0 (14.0)
# Epoch 107/150 | Loss 0.0111 | Win/lose count 14.0/3.0 (11.0)
# Epoch 108/150 | Loss 0.0095 | Win/lose count 13.5/2.0 (11.5)
# Epoch 109/150 | Loss 0.0123 | Win/lose count 12.5/3.0 (9.5)
# Epoch 110/150 | Loss 0.0088 | Win/lose count 21.0/1.0 (20.0)
# Epoch 111/150 | Loss 0.0093 | Win/lose count 17.0/4.0 (13.0)
# Epoch 112/150 | Loss 0.0112 | Win/lose count 20.0/3.0 (17.0)
# Epoch 113/150 | Loss 0.0114 | Win/lose count 13.0/1.0 (12.0)
# Epoch 114/150 | Loss 0.0135 | Win/lose count 11.5/1.0 (10.5)
# Epoch 115/150 | Loss 0.0131 | Win/lose count 14.5/4.0 (10.5)
# Epoch 116/150 | Loss 0.0107 | Win/lose count 20.0/3.0 (17.0)
# Epoch 117/150 | Loss 0.0120 | Win/lose count 17.5/1.0 (16.5)
# Epoch 118/150 | Loss 0.0105 | Win/lose count 14.0/5.0 (9.0)
# Epoch 119/150 | Loss 0.0119 | Win/lose count 15.5/5.0 (10.5)
# Epoch 120/150 | Loss 0.0117 | Win/lose count 14.0/1.0 (13.0)
# Epoch 121/150 | Loss 0.0113 | Win/lose count 12.0/3.0 (9.0)
# Epoch 122/150 | Loss 0.0087 | Win/lose count 10.0/2.0 (8.0)
# Epoch 123/150 | Loss 0.0097 | Win/lose count 21.5/2.0 (19.5)
# Epoch 124/150 | Loss 0.0108 | Win/lose count 16.5/4.0 (12.5)
# Epoch 125/150 | Loss 0.0120 | Win/lose count 18.0/6.0 (12.0)
# Epoch 126/150 | Loss 0.0125 | Win/lose count 23.0/4.0 (19.0)
# Epoch 127/150 | Loss 0.0133 | Win/lose count 12.0/4.0 (8.0)
# Epoch 128/150 | Loss 0.0115 | Win/lose count 17.0/7.0 (10.0)
# Epoch 129/150 | Loss 0.0123 | Win/lose count 8.5/1.0 (7.5)
# Epoch 130/150 | Loss 0.0108 | Win/lose count 14.5/3.0 (11.5)
# Epoch 131/150 | Loss 0.0110 | Win/lose count 15.0/1.0 (14.0)
# Epoch 132/150 | Loss 0.0115 | Win/lose count 19.5/1.0 (18.5)
# Epoch 133/150 | Loss 0.0133 | Win/lose count 15.5/3.0 (12.5)
# Epoch 134/150 | Loss 0.0097 | Win/lose count 20.5/1.0 (19.5)
# Epoch 135/150 | Loss 0.0114 | Win/lose count 15.5/2.0 (13.5)
# Epoch 136/150 | Loss 0.0091 | Win/lose count 21.5/3.0 (18.5)
# Epoch 137/150 | Loss 0.0083 | Win/lose count 8.0/2.0 (6.0)
# Epoch 138/150 | Loss 0.0103 | Win/lose count 13.5/1.0 (12.5)
# Epoch 139/150 | Loss 0.0107 | Win/lose count 18.5/1.0 (17.5)
# Epoch 140/150 | Loss 0.0108 | Win/lose count 15.0/1.0 (14.0)
# Epoch 141/150 | Loss 0.0095 | Win/lose count 15.5/3.0 (12.5)
# Epoch 142/150 | Loss 0.0095 | Win/lose count 16.5/2.0 (14.5)
# Epoch 143/150 | Loss 0.0091 | Win/lose count 18.5/3.0 (15.5)
# Epoch 144/150 | Loss 0.0086 | Win/lose count 20.5/2.0 (18.5)
# Epoch 145/150 | Loss 0.0108 | Win/lose count 17.0/6.0 (11.0)
# Epoch 146/150 | Loss 0.0123 | Win/lose count 14.0/5.0 (9.0)
# Epoch 147/150 | Loss 0.0118 | Win/lose count 14.5/6.0 (8.5)
# Epoch 148/150 | Loss 0.0099 | Win/lose count 12.5/0 (12.5)
# Epoch 149/150 | Loss 0.0098 | Win/lose count 22.5/4.0 (18.5)

# %%
plt.plot(history_losses_dqn_fc,marker="+",color="b",label="dqn_fc")
plt.plot(history_losses_dqn_cnn,marker="+",color="r",label="dqn_cnn")
plt.xlabel("episodes") ; plt.ylabel("average training loss across episod") ; plt.legend()
plt.show()

# %%
plt.plot(history_scores_dqn_fc,marker="+",color="b",label="dqn_fc")
plt.plot(history_scores_dqn_cnn,marker="+",color="r",label="dqn_cnn")
plt.xlabel("episodes") ; plt.ylabel("score at episod (win-lose)") ; plt.legend()
plt.show()

# %%
HTML(display_videos('cnn_train150.mp4')) #last train episode
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.
#
# > The two networks I compared are the two presented above which led the best performances for each type :  the FCN with one hidden layer with 32 neurons (followed by relu), and the CNN with 2 convolutional layers (16 small filters of size (2,2) each followed by relu) and the final dense layer. Recall that I used the samed learning rate of 0.1, the same size of memory of (2000), and the same size of batch (32) for the training of the two networks.
#
# > What's make the comparison particularly interesting is that the two networks architectures, the FC and the CNN, share the same number of parameters (1,764).
#
# > Below is a summary of the test performances obtained for various temperatures, training the agent with constant $\epsilon$=0.1, and for the environment temperature equal to 0.3. Recall that the temperature parameter corresponds to the probability that each cell contains a cheese, and to the probability that each cell which does not contain a cheese contains a poison.
#
#
# | Test temperature | 0.1  | 0.3 | 0.5 |
# |------|------|------|------|
# |  DQN-FC - Test Score | | | | | |
# |  DQN-CNN - Test Score | | | | | |
#
# > Comments : We observe that the higher the test tempertaure, the more the CNN outperforms the FC network. As the two networks have exactly the same capacity (same number of parameters), these experiments tend to show that the convolutional architecture is very appropriate for the task.
#
# > However, we observe the issue that, throughout the training and at test time, the agent has explored only one part of the map.  We can see this behaviour notably when the rat does not see any positive reward around him : in such cases which appear for low environment temperatures, the rat often transits from a state to another to go back to the original one several times. Therefore, I will implement below the two advised strategies to favor exploration : the decreasing $\epsilon$-greedy policy, and the array storing the visited cells by the rat.

# %%
agent_dqn_cnn = DQN_CNN(grid_size=size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_dqn_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_dqn_fc = DQN_FC(grid_size=size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_dqn_fc.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')

for temp in [0.1, 0.3, 0.5]:
    print("TEMPERATURE : ", str(temp))
    env = Environment(grid_size=size, max_time=T,temperature=temp)

    print('Test of the CNN')
    test(agent_dqn_cnn,env,epochs_test,prefix='cnn_test_'+str(temp)+'_')
    print('Test of the FC')
    test(agent_dqn_fc,env,epochs_test,prefix='fc_test_'+str(temp)+'_')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 3, 3, 16)          304
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 16)          2320
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 2,692
# Trainable params: 2,692
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1632
# _________________________________________________________________
# activation_3 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                528
# _________________________________________________________________
# activation_4 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 2,228
# Trainable params: 2,228
# Non-trainable params: 0
# _________________________________________________________________
# TEMPERATURE :  0.1
# Test of the CNN
# Win/lose count 6.0/0. Average score (6.0)
# Win/lose count 1.0/0. Average score (3.5)
# Win/lose count 3.5/0. Average score (3.5)
# Win/lose count 0.5/0. Average score (2.75)
# Win/lose count 0.5/0. Average score (2.3)
# Win/lose count 1.5/0. Average score (2.1666666666666665)
# Win/lose count 2.5/0. Average score (2.2142857142857144)
# Win/lose count 3.5/0. Average score (2.375)
# Win/lose count 2.0/0. Average score (2.3333333333333335)
# Win/lose count 5.5/0. Average score (2.65)
# Win/lose count 3.5/0. Average score (2.727272727272727)
# Win/lose count 4.0/0. Average score (2.8333333333333335)
# Win/lose count 2.0/0. Average score (2.769230769230769)
# Win/lose count 2.0/0. Average score (2.7142857142857144)
# Win/lose count 3.0/0. Average score (2.7333333333333334)
# Win/lose count 8.5/0. Average score (3.09375)
# Win/lose count 4.0/1.0. Average score (3.088235294117647)
# Win/lose count 2.0/0. Average score (3.0277777777777777)
# Win/lose count 1.5/0. Average score (2.9473684210526314)
# Win/lose count 6.0/0. Average score (3.1)
# Win/lose count 2.5/0. Average score (3.0714285714285716)
# Win/lose count 2.5/0. Average score (3.0454545454545454)
# Win/lose count 5.5/0. Average score (3.152173913043478)
# Win/lose count 2.0/0. Average score (3.1041666666666665)
# Win/lose count 3.0/0. Average score (3.1)
# Win/lose count 0.5/0. Average score (3.0)
# Win/lose count 3.0/0. Average score (3.0)
# Win/lose count 4.5/0. Average score (3.0535714285714284)
# Win/lose count 4.5/0. Average score (3.103448275862069)
# Win/lose count 0.5/0. Average score (3.0166666666666666)
# Final score: 3.0166666666666666
# Test of the FC
# Win/lose count 1.0/0. Average score (1.0)
# Win/lose count 1.0/0. Average score (1.0)
# Win/lose count 1.5/0. Average score (1.1666666666666667)
# Win/lose count 0.5/0. Average score (1.0)
# Win/lose count 3.0/0. Average score (1.4)
# Win/lose count 4.5/0. Average score (1.9166666666666667)
# Win/lose count 2.0/0. Average score (1.9285714285714286)
# Win/lose count 2.5/0. Average score (2.0)
# Win/lose count 1.5/0. Average score (1.9444444444444444)
# Win/lose count 1.0/0. Average score (1.85)
# Win/lose count 6.5/0. Average score (2.272727272727273)
# Win/lose count 0.5/0. Average score (2.125)
# Win/lose count 1.0/0. Average score (2.0384615384615383)
# Win/lose count 1.5/0. Average score (2.0)
# Win/lose count 0.5/0. Average score (1.9)
# Win/lose count 0/0. Average score (1.78125)
# Win/lose count 0.5/0. Average score (1.7058823529411764)
# Win/lose count 1.0/0. Average score (1.6666666666666667)
# Win/lose count 3.5/0. Average score (1.763157894736842)
# Win/lose count 1.5/0. Average score (1.75)
# Win/lose count 2.5/0. Average score (1.7857142857142858)
# Win/lose count 2.0/0. Average score (1.7954545454545454)
# Win/lose count 1.0/0. Average score (1.7608695652173914)
# Win/lose count 0.5/0. Average score (1.7083333333333333)
# Win/lose count 0/0. Average score (1.64)
# Win/lose count 1.0/0. Average score (1.6153846153846154)
# Win/lose count 3.0/0. Average score (1.6666666666666667)
# Win/lose count 1.5/0. Average score (1.6607142857142858)
# Win/lose count 2.5/0. Average score (1.6896551724137931)
# Win/lose count 1.5/0. Average score (1.6833333333333333)
# Final score: 1.6833333333333333
# TEMPERATURE :  0.3
# Test of the CNN
# Win/lose count 10.5/0. Average score (10.5)
# Win/lose count 8.0/0. Average score (9.25)
# Win/lose count 2.5/0. Average score (7.0)
# Win/lose count 6.0/0. Average score (6.75)
# Win/lose count 11.5/0. Average score (7.7)
# Win/lose count 2.5/0. Average score (6.833333333333333)
# Win/lose count 5.0/0. Average score (6.571428571428571)
# Win/lose count 14.0/0. Average score (7.5)
# Win/lose count 19.0/0. Average score (8.777777777777779)
# Win/lose count 10.0/0. Average score (8.9)
# Win/lose count 14.5/1.0. Average score (9.318181818181818)
# Win/lose count 1.5/0. Average score (8.666666666666666)
# Win/lose count 8.0/0. Average score (8.615384615384615)
# Win/lose count 13.5/0. Average score (8.964285714285714)
# Win/lose count 6.0/0. Average score (8.766666666666667)
# Win/lose count 6.0/0. Average score (8.59375)
# Win/lose count 4.5/0. Average score (8.352941176470589)
# Win/lose count 3.0/0. Average score (8.055555555555555)
# Win/lose count 9.0/0. Average score (8.105263157894736)
# Win/lose count 6.0/0. Average score (8.0)
# Win/lose count 4.0/0. Average score (7.809523809523809)
# Win/lose count 8.0/0. Average score (7.818181818181818)
# Win/lose count 14.0/0. Average score (8.08695652173913)
# Win/lose count 7.5/0. Average score (8.0625)
# Win/lose count 17.0/0. Average score (8.42)
# Win/lose count 21.5/0. Average score (8.923076923076923)
# Win/lose count 1.0/0. Average score (8.62962962962963)
# Win/lose count 3.0/0. Average score (8.428571428571429)
# Win/lose count 8.0/0. Average score (8.413793103448276)
# Win/lose count 2.0/0. Average score (8.2)
# Final score: 8.2
# Test of the FC
# Win/lose count 4.5/0. Average score (4.5)
# Win/lose count 0.5/0. Average score (2.5)
# Win/lose count 16.0/0. Average score (7.0)
# Win/lose count 1.5/0. Average score (5.625)
# Win/lose count 9.0/0. Average score (6.3)
# Win/lose count 16.5/0. Average score (8.0)
# Win/lose count 5.0/0. Average score (7.571428571428571)
# Win/lose count 6.0/0. Average score (7.375)
# Win/lose count 0.5/0. Average score (6.611111111111111)
# Win/lose count 4.0/0. Average score (6.35)
# Win/lose count 1.5/0. Average score (5.909090909090909)
# Win/lose count 10.5/0. Average score (6.291666666666667)
# Win/lose count 15.0/0. Average score (6.961538461538462)
# Win/lose count 4.5/0. Average score (6.785714285714286)
# Win/lose count 5.5/0. Average score (6.7)
# Win/lose count 8.5/1.0. Average score (6.75)
# Win/lose count 6.5/0. Average score (6.735294117647059)
# Win/lose count 14.0/0. Average score (7.138888888888889)
# Win/lose count 9.0/0. Average score (7.2368421052631575)
# Win/lose count 4.5/1.0. Average score (7.05)
# Win/lose count 5.0/0. Average score (6.9523809523809526)
# Win/lose count 4.5/0. Average score (6.840909090909091)
# Win/lose count 2.0/0. Average score (6.630434782608695)
# Win/lose count 5.5/0. Average score (6.583333333333333)
# Win/lose count 3.5/0. Average score (6.46)
# Win/lose count 2.0/0. Average score (6.288461538461538)
# Win/lose count 11.0/0. Average score (6.462962962962963)
# Win/lose count 2.0/0. Average score (6.303571428571429)
# Win/lose count 5.0/0. Average score (6.258620689655173)
# Win/lose count 10.0/0. Average score (6.383333333333334)
# Final score: 6.383333333333334
# TEMPERATURE :  0.5
# Test of the CNN
# Win/lose count 2.5/1.0. Average score (1.5)
# Win/lose count 20.5/1.0. Average score (10.5)
# Win/lose count 11.5/0. Average score (10.833333333333334)
# Win/lose count 2.5/0. Average score (8.75)
# Win/lose count 1.0/0. Average score (7.2)
# Win/lose count 24.5/0. Average score (10.083333333333334)
# Win/lose count 21.0/0. Average score (11.642857142857142)
# Win/lose count 36.0/0. Average score (14.6875)
# Win/lose count 22.5/0. Average score (15.555555555555555)
# Win/lose count 6.0/0. Average score (14.6)
# Win/lose count 3.5/0. Average score (13.590909090909092)
# Win/lose count 26.5/0. Average score (14.666666666666666)
# Win/lose count 15.0/0. Average score (14.692307692307692)
# Win/lose count 24.0/0. Average score (15.357142857142858)
# Win/lose count 18.5/0. Average score (15.566666666666666)
# Win/lose count 12.0/0. Average score (15.34375)
# Win/lose count 4.5/0. Average score (14.705882352941176)
# Win/lose count 20.5/0. Average score (15.027777777777779)
# Win/lose count 2.5/0. Average score (14.368421052631579)
# Win/lose count 15.5/0. Average score (14.425)
# Win/lose count 10.0/0. Average score (14.214285714285714)
# Win/lose count 5.0/0. Average score (13.795454545454545)
# Win/lose count 12.0/0. Average score (13.717391304347826)
# Win/lose count 8.5/0. Average score (13.5)
# Win/lose count 2.0/2.0. Average score (12.96)
# Win/lose count 28.0/1.0. Average score (13.5)
# Win/lose count 9.5/0. Average score (13.351851851851851)
# Win/lose count 25.0/0. Average score (13.767857142857142)
# Win/lose count 11.0/0. Average score (13.672413793103448)
# Win/lose count 17.0/0. Average score (13.783333333333333)
# Final score: 13.783333333333333
# Test of the FC
# Win/lose count 7.0/0. Average score (7.0)
# Win/lose count 18.0/0. Average score (12.5)
# Win/lose count 11.0/0. Average score (12.0)
# Win/lose count 2.0/0. Average score (9.5)
# Win/lose count 2.5/0. Average score (8.1)
# Win/lose count 4.5/1.0. Average score (7.333333333333333)
# Win/lose count 9.5/0. Average score (7.642857142857143)
# Win/lose count 1.5/0. Average score (6.875)
# Win/lose count 5.5/2.0. Average score (6.5)
# Win/lose count 17.0/0. Average score (7.55)
# Win/lose count 9.0/0. Average score (7.681818181818182)
# Win/lose count 15.0/0. Average score (8.291666666666666)
# Win/lose count 4.5/0. Average score (8.0)
# Win/lose count 10.5/0. Average score (8.178571428571429)
# Win/lose count 3.0/0. Average score (7.833333333333333)
# Win/lose count 5.5/0. Average score (7.6875)
# Win/lose count 4.5/0. Average score (7.5)
# Win/lose count 11.5/0. Average score (7.722222222222222)
# Win/lose count 3.5/0. Average score (7.5)
# Win/lose count 12.0/0. Average score (7.725)
# Win/lose count 3.5/0. Average score (7.523809523809524)
# Win/lose count 8.5/0. Average score (7.568181818181818)
# Win/lose count 12.0/0. Average score (7.760869565217392)
# Win/lose count 12.0/0. Average score (7.9375)
# Win/lose count 11.0/0. Average score (8.06)
# Win/lose count 1.5/0. Average score (7.8076923076923075)
# Win/lose count 12.5/0. Average score (7.981481481481482)
# Win/lose count 11.0/1.0. Average score (8.053571428571429)
# Win/lose count 0.5/0. Average score (7.793103448275862)
# Win/lose count 4.0/0. Average score (7.666666666666667)
# Final score: 7.666666666666667

# %%
print("Temperature : 0.3. FCN-DQN")
HTML(display_videos('fc_test_0.3_1.mp4'))
# Out:
# Temperature : 0.3. FCN-DQN
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
print("Temperature : 0.3. CNN-DQN")
HTML(display_videos('cnn_test_0.3_1.mp4'))
# Out:
# Temperature : 0.3. CNN-DQN
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
print("Temperature : 0.1. CNN-DQN")
HTML(display_videos('cnn_test_0.1_1.mp4'))
# Out:
# Temperature : 0.1. CNN-DQN
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
print("Temperature : 0.5. CNN-DQN")
HTML(display_videos('cnn_test_0.5_1.mp4'))
# Out:
# Temperature : 0.5. CNN-DQN
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.
#
# > Therefore, I trained for this experiment the DQN rat with the same architecture CNN network, except that its input is now of shape (5,5,3), the third "layer" informing the cat whether or not each cell he sees has been visited by the past (1 if visited, 0 otherwise). Thus, the new CNN network had slightly more parameters than the previous one (1828 against 1764). In addition, the new trained rat played according to an $\epsilon$-greedy policy, with $\epsilon$-decreasing linearly from 0.9 to 0.1 across the 100 training epochs.
#
# >In the table below, I report its performances at test time under various temperatures, and compare these to the DQN-CNN rat trained without the "third" layer information, without the reshaped reward (original reward minus the potential malus of having already visite the state), and playing throughout according to a 0.1-$\epsilon$ greedy policy during the whole 100 training epochs.
#
# > | Test temperature | 0.1  | 0.3 | 0.5 |
# |------|------|------|------|
# |  DQN-CNN constant epsilon (0.1) - Test Score | | | | | |
# |  DQN-CNN decreasing epsilon - Test Score | | | | |

# %%
def train_explore(agent,env, epoch, decay_epsilon = 0.1, prefix=''):
    #epoch : number of training epochs
    
    history_losses = []
    history_scores = []    
    
    score = 0
    
    for e in range(epoch):
            
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False
        
        loss = 0

        win = 0
        lose = 0
        
        t = 0

        while not game_over:
            
            # The agent performs an action
            action = agent.act(state, train = True)

            # Apply an action to the environment, get the next state, the reward
            prev_state = state
            state, reward, game_over = env.act(action, train = True)
            
            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss += agent.reinforce(prev_state, state,  action, reward, game_over)
            
            t+=1
            
        loss /= t
            
        history_losses.append(loss)
        
        ############
        #Update epsilon
        agent.set_epsilon(agent.epsilon*(1-decay_epsilon))
        ############

        # Save as a mp4
        if (e+1) % 50 == 0:
            env.draw(prefix+str(e+1))

        # Update stats
        score_episode = win-lose
        score += score_episode
        history_scores.append(score_episode)
        
        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, score_episode))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
                
class EnvironmentExploring(Environment):
    
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        
        super(EnvironmentExploring, self).__init__(grid_size=grid_size, max_time=max_time, temperature=temperature)

        #third information layer (has the cell been visited by the past ?)
        self.malus_position = np.zeros((self.grid_size,self.grid_size))
    
    def act(self, action, train=False):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1 

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x -1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x +1
            else:
                self.x = self.x - 1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        
        reward = self.board[self.x, self.y]
        
        if train: #reshaping the reward if the cell was already visited
            reward -= self.malus_position[self.x, self.y]
            
        #the cell has just been visited
        self.malus_position[self.x, self.y] = 0.1
        
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
                
        #we have one more layer caracterizing a state now
        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        
        #state visible for the rat
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]
        
        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1 
        
        #third information layer (has the cell been visited by the past ?)
        self.malus_position = np.zeros((self.grid_size,self.grid_size))
        
        self.board[self.x,self.y] = 0
        self.board[self.position < 0] = 0
        
        self.t = 0
        
        #the initial state is visited
        self.malus_position[self.x, self.y] = 0.1
        
        #we have one more layer caracterizing a state now
        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=temperature)

agent_dqn_cnn_explore = DQN_CNN(grid_size=size, lr=.1, epsilon = 0.95, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent_dqn_cnn_explore, env, epochs_train, decay_epsilon = 0.05, prefix='cnn_train_explore')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 3, 3, 16)          448
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 1, 1, 16)          2320
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 16)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 2,836
# Trainable params: 2,836
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/150 | Loss 0.0222 | Win/lose count 11.5/21.90000000000005 (-10.400000000000048)
# Epoch 001/150 | Loss 0.0165 | Win/lose count 9.5/27.40000000000011 (-17.90000000000011)
# Epoch 002/150 | Loss 0.0160 | Win/lose count 15.0/22.400000000000023 (-7.4000000000000234)
# Epoch 003/150 | Loss 0.0151 | Win/lose count 12.5/29.70000000000008 (-17.20000000000008)
# Epoch 004/150 | Loss 0.0161 | Win/lose count 8.5/24.400000000000027 (-15.900000000000027)
# Epoch 005/150 | Loss 0.0116 | Win/lose count 9.5/24.60000000000003 (-15.10000000000003)
# Epoch 006/150 | Loss 0.0151 | Win/lose count 18.0/20.700000000000042 (-2.700000000000042)
# Epoch 007/150 | Loss 0.0133 | Win/lose count 14.5/27.800000000000065 (-13.300000000000065)
# Epoch 008/150 | Loss 0.0139 | Win/lose count 14.0/22.800000000000054 (-8.800000000000054)
# Epoch 009/150 | Loss 0.0148 | Win/lose count 10.5/21.700000000000024 (-11.200000000000024)
# Epoch 010/150 | Loss 0.0138 | Win/lose count 15.0/23.60000000000004 (-8.60000000000004)
# Epoch 011/150 | Loss 0.0155 | Win/lose count 12.5/22.70000000000001 (-10.20000000000001)
# Epoch 012/150 | Loss 0.0149 | Win/lose count 15.0/20.700000000000028 (-5.700000000000028)
# Epoch 013/150 | Loss 0.0134 | Win/lose count 13.0/22.500000000000057 (-9.500000000000057)
# Epoch 014/150 | Loss 0.0138 | Win/lose count 12.0/19.29999999999999 (-7.29999999999999)
# Epoch 015/150 | Loss 0.0127 | Win/lose count 21.0/20.200000000000028 (0.7999999999999723)
# Epoch 016/150 | Loss 0.0131 | Win/lose count 13.5/16.599999999999977 (-3.0999999999999766)
# Epoch 017/150 | Loss 0.0116 | Win/lose count 11.0/20.0 (-9.0)
# Epoch 018/150 | Loss 0.0134 | Win/lose count 22.0/17.499999999999993 (4.500000000000007)
# Epoch 019/150 | Loss 0.0144 | Win/lose count 13.5/17.899999999999974 (-4.399999999999974)
# Epoch 020/150 | Loss 0.0136 | Win/lose count 14.5/18.400000000000006 (-3.9000000000000057)
# Epoch 021/150 | Loss 0.0147 | Win/lose count 19.0/21.100000000000037 (-2.100000000000037)
# Epoch 022/150 | Loss 0.0130 | Win/lose count 5.0/18.499999999999996 (-13.499999999999996)
# Epoch 023/150 | Loss 0.0125 | Win/lose count 17.5/20.0 (-2.5)
# Epoch 024/150 | Loss 0.0123 | Win/lose count 18.5/20.9 (-2.3999999999999986)
# Epoch 025/150 | Loss 0.0136 | Win/lose count 12.5/17.999999999999996 (-5.4999999999999964)
# Epoch 026/150 | Loss 0.0127 | Win/lose count 11.0/18.500000000000004 (-7.5000000000000036)
# Epoch 027/150 | Loss 0.0143 | Win/lose count 16.0/20.100000000000016 (-4.100000000000016)
# Epoch 028/150 | Loss 0.0136 | Win/lose count 21.5/14.69999999999997 (6.800000000000029)
# Epoch 029/150 | Loss 0.0135 | Win/lose count 16.5/18.800000000000008 (-2.300000000000008)
# Epoch 030/150 | Loss 0.0140 | Win/lose count 20.5/17.69999999999999 (2.8000000000000114)
# Epoch 031/150 | Loss 0.0137 | Win/lose count 20.5/16.699999999999978 (3.800000000000022)
# Epoch 032/150 | Loss 0.0139 | Win/lose count 22.5/16.599999999999984 (5.900000000000016)
# Epoch 033/150 | Loss 0.0136 | Win/lose count 18.0/17.099999999999984 (0.9000000000000163)
# Epoch 034/150 | Loss 0.0139 | Win/lose count 21.0/18.20000000000001 (2.79999999999999)
# Epoch 035/150 | Loss 0.0142 | Win/lose count 25.0/13.499999999999975 (11.500000000000025)
# Epoch 036/150 | Loss 0.0151 | Win/lose count 25.0/14.89999999999997 (10.10000000000003)
# Epoch 037/150 | Loss 0.0146 | Win/lose count 21.5/12.499999999999979 (9.000000000000021)
# Epoch 038/150 | Loss 0.0138 | Win/lose count 19.5/17.599999999999994 (1.9000000000000057)
# Epoch 039/150 | Loss 0.0140 | Win/lose count 24.0/12.299999999999972 (11.700000000000028)
# Epoch 040/150 | Loss 0.0134 | Win/lose count 24.0/12.399999999999979 (11.600000000000021)
# Epoch 041/150 | Loss 0.0131 | Win/lose count 16.0/16.39999999999997 (-0.39999999999997016)
# Epoch 042/150 | Loss 0.0140 | Win/lose count 23.5/13.199999999999976 (10.300000000000024)
# Epoch 043/150 | Loss 0.0134 | Win/lose count 25.0/10.699999999999978 (14.300000000000022)
# Epoch 044/150 | Loss 0.0139 | Win/lose count 24.5/13.099999999999973 (11.400000000000027)
# Epoch 045/150 | Loss 0.0133 | Win/lose count 25.5/12.499999999999979 (13.000000000000021)
# Epoch 046/150 | Loss 0.0129 | Win/lose count 22.0/13.999999999999966 (8.000000000000034)
# Epoch 047/150 | Loss 0.0131 | Win/lose count 18.0/14.799999999999967 (3.200000000000033)
# Epoch 048/150 | Loss 0.0123 | Win/lose count 21.5/14.999999999999975 (6.500000000000025)
# Epoch 049/150 | Loss 0.0135 | Win/lose count 25.5/13.999999999999968 (11.500000000000032)
# Epoch 050/150 | Loss 0.0132 | Win/lose count 19.5/13.899999999999974 (5.600000000000026)
# Epoch 051/150 | Loss 0.0125 | Win/lose count 21.5/13.899999999999974 (7.600000000000026)
# Epoch 052/150 | Loss 0.0125 | Win/lose count 23.5/13.799999999999978 (9.700000000000022)
# Epoch 053/150 | Loss 0.0130 | Win/lose count 23.5/13.499999999999975 (10.000000000000025)
# Epoch 054/150 | Loss 0.0134 | Win/lose count 19.0/15.099999999999973 (3.900000000000027)
# Epoch 055/150 | Loss 0.0125 | Win/lose count 26.5/12.099999999999977 (14.400000000000023)
# Epoch 056/150 | Loss 0.0130 | Win/lose count 23.5/10.599999999999984 (12.900000000000016)
# Epoch 057/150 | Loss 0.0133 | Win/lose count 26.0/12.599999999999977 (13.400000000000023)
# Epoch 058/150 | Loss 0.0135 | Win/lose count 24.5/13.19999999999997 (11.30000000000003)
# Epoch 059/150 | Loss 0.0136 | Win/lose count 18.5/11.099999999999977 (7.4000000000000234)
# Epoch 060/150 | Loss 0.0127 | Win/lose count 27.5/12.099999999999978 (15.400000000000022)
# Epoch 061/150 | Loss 0.0128 | Win/lose count 18.5/11.399999999999975 (7.1000000000000245)
# Epoch 062/150 | Loss 0.0126 | Win/lose count 27.5/10.399999999999983 (17.100000000000016)
# Epoch 063/150 | Loss 0.0118 | Win/lose count 19.0/12.599999999999978 (6.400000000000022)
# Epoch 064/150 | Loss 0.0118 | Win/lose count 19.5/14.799999999999963 (4.700000000000037)
# Epoch 065/150 | Loss 0.0128 | Win/lose count 22.0/11.599999999999975 (10.400000000000025)
# Epoch 066/150 | Loss 0.0131 | Win/lose count 27.5/11.199999999999978 (16.300000000000022)
# Epoch 067/150 | Loss 0.0119 | Win/lose count 14.0/14.599999999999968 (-0.5999999999999677)
# Epoch 068/150 | Loss 0.0118 | Win/lose count 29.0/9.99999999999998 (19.00000000000002)
# Epoch 069/150 | Loss 0.0111 | Win/lose count 20.0/12.499999999999975 (7.500000000000025)
# Epoch 070/150 | Loss 0.0117 | Win/lose count 26.0/11.39999999999998 (14.60000000000002)
# Epoch 071/150 | Loss 0.0127 | Win/lose count 18.0/13.49999999999997 (4.50000000000003)
# Epoch 072/150 | Loss 0.0124 | Win/lose count 22.0/11.899999999999977 (10.100000000000023)
# Epoch 073/150 | Loss 0.0122 | Win/lose count 19.0/13.199999999999973 (5.800000000000027)
# Epoch 074/150 | Loss 0.0119 | Win/lose count 21.5/10.199999999999983 (11.300000000000017)
# Epoch 075/150 | Loss 0.0122 | Win/lose count 17.0/11.999999999999975 (5.000000000000025)
# Epoch 076/150 | Loss 0.0119 | Win/lose count 22.5/9.99999999999998 (12.50000000000002)
# Epoch 077/150 | Loss 0.0125 | Win/lose count 17.0/14.09999999999997 (2.9000000000000306)
# Epoch 078/150 | Loss 0.0136 | Win/lose count 26.5/12.799999999999974 (13.700000000000026)
# Epoch 079/150 | Loss 0.0143 | Win/lose count 21.0/12.199999999999973 (8.800000000000027)
# Epoch 080/150 | Loss 0.0150 | Win/lose count 27.5/10.799999999999985 (16.700000000000017)
# Epoch 081/150 | Loss 0.0141 | Win/lose count 23.5/10.599999999999982 (12.900000000000018)
# Epoch 082/150 | Loss 0.0148 | Win/lose count 30.0/12.99999999999998 (17.00000000000002)
# Epoch 083/150 | Loss 0.0153 | Win/lose count 21.5/9.599999999999982 (11.900000000000018)
# Epoch 084/150 | Loss 0.0153 | Win/lose count 25.0/8.299999999999986 (16.700000000000014)
# Epoch 085/150 | Loss 0.0156 | Win/lose count 19.5/11.799999999999978 (7.700000000000022)
# Epoch 086/150 | Loss 0.0151 | Win/lose count 22.5/13.299999999999976 (9.200000000000024)
# Epoch 087/150 | Loss 0.0154 | Win/lose count 22.0/13.099999999999971 (8.900000000000029)
# Epoch 088/150 | Loss 0.0150 | Win/lose count 23.5/11.099999999999977 (12.400000000000023)
# Epoch 089/150 | Loss 0.0153 | Win/lose count 24.0/16.599999999999984 (7.400000000000016)
# Epoch 090/150 | Loss 0.0153 | Win/lose count 24.0/13.79999999999997 (10.20000000000003)
# Epoch 091/150 | Loss 0.0156 | Win/lose count 26.5/11.799999999999976 (14.700000000000024)
# Epoch 092/150 | Loss 0.0155 | Win/lose count 23.0/12.99999999999997 (10.00000000000003)
# Epoch 093/150 | Loss 0.0153 | Win/lose count 23.0/12.999999999999977 (10.000000000000023)
# Epoch 094/150 | Loss 0.0163 | Win/lose count 27.0/8.799999999999985 (18.200000000000017)
# Epoch 095/150 | Loss 0.0152 | Win/lose count 21.5/12.999999999999973 (8.500000000000027)
# Epoch 096/150 | Loss 0.0154 | Win/lose count 20.5/13.69999999999997 (6.800000000000029)
# Epoch 097/150 | Loss 0.0147 | Win/lose count 18.5/13.699999999999974 (4.800000000000026)
# Epoch 098/150 | Loss 0.0147 | Win/lose count 22.0/12.799999999999972 (9.200000000000028)
# Epoch 099/150 | Loss 0.0155 | Win/lose count 26.0/9.199999999999983 (16.80000000000002)
# Epoch 100/150 | Loss 0.0155 | Win/lose count 24.0/12.299999999999974 (11.700000000000026)
# Epoch 101/150 | Loss 0.0154 | Win/lose count 14.5/16.199999999999967 (-1.6999999999999673)
# Epoch 102/150 | Loss 0.0156 | Win/lose count 23.5/14.199999999999983 (9.300000000000017)
# Epoch 103/150 | Loss 0.0167 | Win/lose count 28.5/12.299999999999978 (16.200000000000024)
# Epoch 104/150 | Loss 0.0160 | Win/lose count 19.0/16.299999999999972 (2.7000000000000277)
# Epoch 105/150 | Loss 0.0171 | Win/lose count 24.5/10.799999999999981 (13.700000000000019)
# Epoch 106/150 | Loss 0.0162 | Win/lose count 24.5/11.899999999999974 (12.600000000000026)
# Epoch 107/150 | Loss 0.0169 | Win/lose count 15.0/14.299999999999965 (0.7000000000000348)
# Epoch 108/150 | Loss 0.0164 | Win/lose count 17.5/15.799999999999962 (1.7000000000000384)
# Epoch 109/150 | Loss 0.0165 | Win/lose count 20.0/15.99999999999997 (4.00000000000003)
# Epoch 110/150 | Loss 0.0176 | Win/lose count 25.0/9.899999999999986 (15.100000000000014)
# Epoch 111/150 | Loss 0.0173 | Win/lose count 25.0/11.399999999999975 (13.600000000000025)
# Epoch 112/150 | Loss 0.0181 | Win/lose count 23.0/10.99999999999998 (12.00000000000002)
# Epoch 113/150 | Loss 0.0181 | Win/lose count 21.5/11.899999999999974 (9.600000000000026)
# Epoch 114/150 | Loss 0.0169 | Win/lose count 22.5/10.399999999999983 (12.100000000000017)
# Epoch 115/150 | Loss 0.0153 | Win/lose count 15.5/14.099999999999966 (1.400000000000034)
# Epoch 116/150 | Loss 0.0150 | Win/lose count 25.5/13.299999999999976 (12.200000000000024)
# Epoch 117/150 | Loss 0.0155 | Win/lose count 20.0/14.599999999999968 (5.400000000000032)
# Epoch 118/150 | Loss 0.0162 | Win/lose count 11.0/17.799999999999972 (-6.799999999999972)
# Epoch 119/150 | Loss 0.0165 | Win/lose count 20.0/12.999999999999977 (7.000000000000023)
# Epoch 120/150 | Loss 0.0163 | Win/lose count 24.5/13.799999999999978 (10.700000000000022)
# Epoch 121/150 | Loss 0.0166 | Win/lose count 19.0/10.99999999999998 (8.00000000000002)
# Epoch 122/150 | Loss 0.0161 | Win/lose count 14.0/15.199999999999964 (-1.1999999999999638)
# Epoch 123/150 | Loss 0.0158 | Win/lose count 14.0/13.199999999999976 (0.8000000000000238)
# Epoch 124/150 | Loss 0.0156 | Win/lose count 14.5/13.399999999999968 (1.1000000000000316)
# Epoch 125/150 | Loss 0.0147 | Win/lose count 18.5/15.499999999999963 (3.0000000000000373)
# Epoch 126/150 | Loss 0.0149 | Win/lose count 24.5/9.999999999999984 (14.500000000000016)
# Epoch 127/150 | Loss 0.0149 | Win/lose count 26.0/9.499999999999982 (16.500000000000018)
# Epoch 128/150 | Loss 0.0142 | Win/lose count 20.5/15.499999999999961 (5.000000000000039)
# Epoch 129/150 | Loss 0.0152 | Win/lose count 26.0/9.599999999999982 (16.40000000000002)
# Epoch 130/150 | Loss 0.0153 | Win/lose count 22.0/13.399999999999972 (8.600000000000028)
# Epoch 131/150 | Loss 0.0146 | Win/lose count 23.5/14.499999999999975 (9.000000000000025)
# Epoch 132/150 | Loss 0.0149 | Win/lose count 22.5/14.399999999999965 (8.100000000000035)
# Epoch 133/150 | Loss 0.0171 | Win/lose count 27.5/13.799999999999978 (13.700000000000022)
# Epoch 134/150 | Loss 0.0169 | Win/lose count 24.0/12.599999999999977 (11.400000000000023)
# Epoch 135/150 | Loss 0.0176 | Win/lose count 22.5/9.799999999999986 (12.700000000000014)
# Epoch 136/150 | Loss 0.0179 | Win/lose count 25.5/12.299999999999978 (13.200000000000022)
# Epoch 137/150 | Loss 0.0173 | Win/lose count 19.0/9.99999999999998 (9.00000000000002)
# Epoch 138/150 | Loss 0.0181 | Win/lose count 31.5/12.99999999999998 (18.50000000000002)
# Epoch 139/150 | Loss 0.0174 | Win/lose count 22.0/10.599999999999984 (11.400000000000016)
# Epoch 140/150 | Loss 0.0171 | Win/lose count 25.0/11.199999999999976 (13.800000000000024)
# Epoch 141/150 | Loss 0.0179 | Win/lose count 23.0/9.299999999999985 (13.700000000000015)
# Epoch 142/150 | Loss 0.0188 | Win/lose count 26.0/9.999999999999984 (16.000000000000014)
# Epoch 143/150 | Loss 0.0194 | Win/lose count 22.0/9.499999999999982 (12.500000000000018)
# Epoch 144/150 | Loss 0.0199 | Win/lose count 24.0/12.699999999999976 (11.300000000000024)
# Epoch 145/150 | Loss 0.0201 | Win/lose count 13.5/17.799999999999983 (-4.299999999999983)
# Epoch 146/150 | Loss 0.0187 | Win/lose count 29.0/10.199999999999987 (18.80000000000001)
# Epoch 147/150 | Loss 0.0192 | Win/lose count 22.5/14.899999999999979 (7.600000000000021)
# Epoch 148/150 | Loss 0.0200 | Win/lose count 24.0/10.299999999999983 (13.700000000000017)
# Epoch 149/150 | Loss 0.0192 | Win/lose count 26.0/10.399999999999979 (15.600000000000021)

# %%
HTML(display_videos('cnn_train_explore150.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Comparison

agent_dqn_cnn_explore = DQN_CNN(grid_size=size, lr=.1, epsilon = 0.9, memory_size=2000, batch_size = 32,n_state=3)
agent_dqn_cnn_explore.load(name_weights='cnn_train_exploremodel.h5',name_model='cnn_train_exploremodel.json')

for temp in [0.1, 0.3, 0.5]:
    print("TEMPERATURE : ", str(temp))
    env = EnvironmentExploring(grid_size=size, max_time=T,temperature=temp)

    print('Test of the CNN-DQN with exploration encouragement')
    test(agent_dqn_cnn_explore,env,epochs_test,prefix='cnn_test_explore_'+str(temp)+'_')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 3, 3, 16)          448
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 1, 1, 16)          2320
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 16)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 2,836
# Trainable params: 2,836
# Non-trainable params: 0
# _________________________________________________________________
# TEMPERATURE :  0.1
# Test of the CNN-DQN with exploration encouragement
# Win/lose count 7.0/0. Average score (7.0)
# Win/lose count 8.5/0. Average score (7.75)
# Win/lose count 6.0/0. Average score (7.166666666666667)
# Win/lose count 8.5/0. Average score (7.5)
# Win/lose count 5.5/0. Average score (7.1)
# Win/lose count 7.5/1.0. Average score (7.0)
# Win/lose count 5.0/2.0. Average score (6.428571428571429)
# Win/lose count 8.0/2.0. Average score (6.375)
# Win/lose count 10.0/0. Average score (6.777777777777778)
# Win/lose count 8.0/0. Average score (6.9)
# Win/lose count 11.5/1.0. Average score (7.2272727272727275)
# Win/lose count 9.5/0. Average score (7.416666666666667)
# Win/lose count 4.5/2.0. Average score (7.038461538461538)
# Win/lose count 10.5/0. Average score (7.285714285714286)
# Win/lose count 7.5/0. Average score (7.3)
# Win/lose count 10.0/1.0. Average score (7.40625)
# Win/lose count 7.0/0. Average score (7.382352941176471)
# Win/lose count 9.5/0. Average score (7.5)
# Win/lose count 5.0/1.0. Average score (7.315789473684211)
# Win/lose count 8.0/0. Average score (7.35)
# Win/lose count 8.5/1.0. Average score (7.357142857142857)
# Win/lose count 6.0/0. Average score (7.295454545454546)
# Win/lose count 9.5/0. Average score (7.391304347826087)
# Win/lose count 6.5/0. Average score (7.354166666666667)
# Win/lose count 7.5/0. Average score (7.36)
# Win/lose count 8.5/1.0. Average score (7.365384615384615)
# Win/lose count 6.5/2.0. Average score (7.2592592592592595)
# Win/lose count 9.0/0. Average score (7.321428571428571)
# Win/lose count 7.5/1.0. Average score (7.293103448275862)
# Win/lose count 9.5/0. Average score (7.366666666666666)
# Final score: 7.366666666666666
# TEMPERATURE :  0.3
# Test of the CNN-DQN with exploration encouragement
# Win/lose count 11.0/1.0. Average score (10.0)
# Win/lose count 27.0/2.0. Average score (17.5)
# Win/lose count 17.0/5.0. Average score (15.666666666666666)
# Win/lose count 23.5/3.0. Average score (16.875)
# Win/lose count 24.5/0. Average score (18.4)
# Win/lose count 22.5/2.0. Average score (18.75)
# Win/lose count 22.5/1.0. Average score (19.142857142857142)
# Win/lose count 22.5/2.0. Average score (19.3125)
# Win/lose count 12.5/1.0. Average score (18.444444444444443)
# Win/lose count 25.5/1.0. Average score (19.05)
# Win/lose count 18.0/2.0. Average score (18.772727272727273)
# Win/lose count 26.0/2.0. Average score (19.208333333333332)
# Win/lose count 22.0/2.0. Average score (19.26923076923077)
# Win/lose count 21.0/4.0. Average score (19.107142857142858)
# Win/lose count 17.0/2.0. Average score (18.833333333333332)
# Win/lose count 22.5/1.0. Average score (19.0)
# Win/lose count 21.5/2.0. Average score (19.029411764705884)
# Win/lose count 23.5/3.0. Average score (19.11111111111111)
# Win/lose count 20.0/1.0. Average score (19.105263157894736)
# Win/lose count 23.5/3.0. Average score (19.175)
# Win/lose count 22.0/3.0. Average score (19.166666666666668)
# Win/lose count 23.0/2.0. Average score (19.25)
# Win/lose count 22.5/1.0. Average score (19.347826086956523)
# Win/lose count 12.0/2.0. Average score (18.958333333333332)
# Win/lose count 22.0/2.0. Average score (19.0)
# Win/lose count 21.5/3.0. Average score (18.98076923076923)
# Win/lose count 28.5/3.0. Average score (19.22222222222222)
# Win/lose count 17.0/1.0. Average score (19.107142857142858)
# Win/lose count 16.5/4.0. Average score (18.879310344827587)
# Win/lose count 25.5/1.0. Average score (19.066666666666666)
# Final score: 19.066666666666666
# TEMPERATURE :  0.5
# Test of the CNN-DQN with exploration encouragement
# Win/lose count 34.0/2.0. Average score (32.0)
# Win/lose count 38.0/1.0. Average score (34.5)
# Win/lose count 36.5/6.0. Average score (33.166666666666664)
# Win/lose count 35.0/7.0. Average score (31.875)
# Win/lose count 35.0/8.0. Average score (30.9)
# Win/lose count 37.5/5.0. Average score (31.166666666666668)
# Win/lose count 43.5/2.0. Average score (32.642857142857146)
# Win/lose count 26.0/1.0. Average score (31.6875)
# Win/lose count 41.5/4.0. Average score (32.333333333333336)
# Win/lose count 36.0/3.0. Average score (32.4)
# Win/lose count 30.0/4.0. Average score (31.818181818181817)
# Win/lose count 35.0/5.0. Average score (31.666666666666668)
# Win/lose count 35.5/4.0. Average score (31.653846153846153)
# Win/lose count 31.5/8.0. Average score (31.071428571428573)
# Win/lose count 38.0/3.0. Average score (31.333333333333332)
# Win/lose count 40.5/8.0. Average score (31.40625)
# Win/lose count 44.0/5.0. Average score (31.852941176470587)
# Win/lose count 35.0/9.0. Average score (31.52777777777778)
# Win/lose count 40.5/8.0. Average score (31.57894736842105)
# Win/lose count 30.5/6.0. Average score (31.225)
# Win/lose count 39.5/4.0. Average score (31.428571428571427)
# Win/lose count 42.5/3.0. Average score (31.795454545454547)
# Win/lose count 32.0/6.0. Average score (31.543478260869566)
# Win/lose count 29.5/4.0. Average score (31.291666666666668)
# Win/lose count 35.0/3.0. Average score (31.32)
# Win/lose count 21.0/4.0. Average score (30.76923076923077)
# Win/lose count 23.0/2.0. Average score (30.40740740740741)
# Win/lose count 33.0/6.0. Average score (30.285714285714285)
# Win/lose count 39.5/7.0. Average score (30.362068965517242)
# Win/lose count 6.5/0. Average score (29.566666666666666)
# Final score: 29.566666666666666

# %%
# Evaluation
print("Temperature : 0.1. CNN-DQN with encouraged exploration.")
HTML(display_videos('cnn_test_explore_0.1_1.mp4'))
# Out:
# Temperature : 0.1. CNN-DQN with encouraged exploration.
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
print("Temperature : 0.3. CNN-DQN with encouraged exploration.")
HTML(display_videos('cnn_test_explore_0.3_1.mp4'))
# Out:
# Temperature : 0.3. CNN-DQN with encouraged exploration.
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
print("Temperature : 0.5. CNN-DQN with encouraged exploration.")
HTML(display_videos('cnn_test_explore_0.5_1.mp4'))
# Out:
# Temperature : 0.5. CNN-DQN with encouraged exploration.
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.

# %% [markdown]
# > To this end, I collected 10 test trajectories of horizon T=100 of the best DQN agent previously trained (CNN with exploration tricks). Then I trained a "Mimicker Agent", which is not more than a CNN, which aims at predicting which action is taken by the expert DQN (values form 0 to 3) from the input state. I again used for the CNN architecture 2 convolutional layers (16 small filters of size (2,2) each followed by relu) and a final dense layer, and I used the categorical cross-entropy loss, adequate for this classification task.
#
# >In the table below, I report the performances at test time, under various temperatures, of the Mimicker Agent, against those of the expert DQN Agent.
#
# > | Test temperature | 0.1  | 0.3 | 0.5 |
# |------|------|------|------|
# |  DQN-CNN Expert - Test Score | | | | | |
# |  CNN Mimicker - Test Score | | | | |
#
#
# ##### TODO : http://ciml.info/dl/v0_99/ciml-v0_99-ch18.pdf

# %% [markdown]
# ***

# %%
class Mimicker():
    
    def __init__(self, n_state=2, n_action=4):
        
        # number of action
        self.n_action = n_action
        
        # number of state
        self.n_state = n_state
        
        # Batch size when learning
                
        model = Sequential()
    
        model.add(Conv2D(16, (3, 3), activation='relu', input_shape=(5,5,self.n_state,)))
        #model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Conv2D(16, (3, 3), activation='relu'))
        #model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Flatten())
        model.add(Dense(self.n_action,activation='softmax'))

        model.summary()
        
        opt = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
        #opt = sgd(lr=lr, decay=1e-4, momentum=0.0)
        model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
        
        self.model = model
    
    def act(self,state,train=True):
        return np.argmax(self.model.predict(state[None,:,:,:]).flatten()) #action with highest probability
        
    def learn(self,demonstrations,epochs=100,batch_size=16,prefix='', viz=True):
        
        nb_samples = len(demonstrations)
        states = np.zeros((nb_samples,5,5,self.n_state))
        actions = np.zeros((nb_samples,self.n_action))
        for (idx,(state, action)) in enumerate(demonstrations):
            states[idx] = state 
            actions[idx] = to_categorical(action,self.n_action)
                                
        early_stopping_monitor = EarlyStopping(patience = 5)
        
        history = self.model.fit(states,actions,
                                 batch_size=batch_size,epochs=epochs,
                                 validation_split = 0.2,callbacks=[early_stopping_monitor],
                                 verbose=1)
        
        if viz:
            plt.plot(history.history['loss'],marker="+",color="b",label="train")
            plt.plot(history.history['val_loss'],marker="+",color="r",label="valid")
            plt.xlabel("epochs") ; plt.ylabel("loss") ; plt.legend()
            plt.show()

        self.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        
        opt = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
        #opt = sgd(lr=lr, decay=1e-4, momentum=0.0)
        model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])  
        
        self.model = model

# %%
nb_demonstrations = 100
env = EnvironmentExploring(grid_size=size, max_time=T,temperature=temperature)
demonstrations = test(agent_dqn_cnn_explore,env,nb_demonstrations,prefix='cnn_test_explore', return_trajectories=True)
# Out:
# Win/lose count 19.5/2.0. Average score (17.5)
# Win/lose count 25.0/2.0. Average score (20.25)
# Win/lose count 18.0/4.0. Average score (18.166666666666668)
# Win/lose count 28.5/0. Average score (20.75)
# Win/lose count 23.0/3.0. Average score (20.6)
# Win/lose count 23.0/3.0. Average score (20.5)
# Win/lose count 24.0/5.0. Average score (20.285714285714285)
# Win/lose count 21.0/3.0. Average score (20.0)
# Win/lose count 19.0/0. Average score (19.88888888888889)
# Win/lose count 26.5/4.0. Average score (20.15)
# Win/lose count 19.0/1.0. Average score (19.954545454545453)
# Win/lose count 29.0/3.0. Average score (20.458333333333332)
# Win/lose count 14.0/0. Average score (19.96153846153846)
# Win/lose count 21.0/2.0. Average score (19.892857142857142)
# Win/lose count 26.0/4.0. Average score (20.033333333333335)
# Win/lose count 24.0/3.0. Average score (20.09375)
# Win/lose count 22.0/3.0. Average score (20.029411764705884)
# Win/lose count 16.5/2.0. Average score (19.72222222222222)
# Win/lose count 26.0/2.0. Average score (19.94736842105263)
# Win/lose count 19.5/2.0. Average score (19.825)
# Win/lose count 12.5/2.0. Average score (19.38095238095238)
# Win/lose count 20.5/3.0. Average score (19.295454545454547)
# Win/lose count 22.0/4.0. Average score (19.23913043478261)
# Win/lose count 23.5/3.0. Average score (19.291666666666668)
# Win/lose count 24.5/6.0. Average score (19.26)
# Win/lose count 12.5/1.0. Average score (18.96153846153846)
# Win/lose count 11.0/1.0. Average score (18.62962962962963)
# Win/lose count 17.0/1.0. Average score (18.535714285714285)
# Win/lose count 16.5/2.0. Average score (18.396551724137932)
# Win/lose count 14.0/4.0. Average score (18.116666666666667)
# Win/lose count 23.0/0. Average score (18.274193548387096)
# Win/lose count 21.5/2.0. Average score (18.3125)
# Win/lose count 17.5/2.0. Average score (18.227272727272727)
# Win/lose count 25.0/2.0. Average score (18.36764705882353)
# Win/lose count 26.0/0. Average score (18.585714285714285)
# Win/lose count 22.5/3.0. Average score (18.61111111111111)
# Win/lose count 17.5/4.0. Average score (18.472972972972972)
# Win/lose count 19.0/3.0. Average score (18.407894736842106)
# Win/lose count 21.0/1.0. Average score (18.44871794871795)
# Win/lose count 12.0/0. Average score (18.2875)
# Win/lose count 19.5/1.0. Average score (18.29268292682927)
# Win/lose count 28.5/5.0. Average score (18.416666666666668)
# Win/lose count 36.5/4.0. Average score (18.74418604651163)
# Win/lose count 23.0/2.0. Average score (18.795454545454547)
# Win/lose count 25.5/3.0. Average score (18.877777777777776)
# Win/lose count 19.5/4.0. Average score (18.804347826086957)
# Win/lose count 25.0/2.0. Average score (18.893617021276597)
# Win/lose count 19.5/2.0. Average score (18.864583333333332)
# Win/lose count 20.0/0. Average score (18.887755102040817)
# Win/lose count 24.5/1.0. Average score (18.98)
# Win/lose count 13.0/0. Average score (18.862745098039216)
# Win/lose count 18.5/3.0. Average score (18.798076923076923)
# Win/lose count 12.0/2.0. Average score (18.632075471698112)
# Win/lose count 9.5/3.0. Average score (18.40740740740741)
# Win/lose count 18.5/0. Average score (18.40909090909091)
# Win/lose count 25.0/2.0. Average score (18.491071428571427)
# Win/lose count 10.0/1.0. Average score (18.32456140350877)
# Win/lose count 21.5/0. Average score (18.379310344827587)
# Win/lose count 19.5/0. Average score (18.39830508474576)
# Win/lose count 29.0/2.0. Average score (18.541666666666668)
# Win/lose count 16.5/1.0. Average score (18.491803278688526)
# Win/lose count 20.5/0. Average score (18.524193548387096)
# Win/lose count 23.0/3.0. Average score (18.547619047619047)
# Win/lose count 22.5/3.0. Average score (18.5625)
# Win/lose count 28.5/4.0. Average score (18.653846153846153)
# Win/lose count 14.0/3.0. Average score (18.53787878787879)
# Win/lose count 17.5/2.0. Average score (18.492537313432837)
# Win/lose count 17.5/2.0. Average score (18.448529411764707)
# Win/lose count 26.0/3.0. Average score (18.514492753623188)
# Win/lose count 19.5/1.0. Average score (18.514285714285716)
# Win/lose count 27.5/2.0. Average score (18.612676056338028)
# Win/lose count 26.0/5.0. Average score (18.645833333333332)
# Win/lose count 27.5/5.0. Average score (18.698630136986303)
# Win/lose count 21.5/2.0. Average score (18.70945945945946)
# Win/lose count 13.5/0. Average score (18.64)
# Win/lose count 17.5/3.0. Average score (18.585526315789473)
# Win/lose count 17.0/2.0. Average score (18.538961038961038)
# Win/lose count 17.5/0. Average score (18.525641025641026)
# Win/lose count 25.0/7.0. Average score (18.518987341772153)
# Win/lose count 17.5/2.0. Average score (18.48125)
# Win/lose count 22.0/3.0. Average score (18.487654320987655)
# Win/lose count 24.0/2.0. Average score (18.53048780487805)
# Win/lose count 25.0/2.0. Average score (18.58433734939759)
# Win/lose count 22.5/4.0. Average score (18.583333333333332)
# Win/lose count 21.0/3.0. Average score (18.576470588235296)
# Win/lose count 20.0/6.0. Average score (18.523255813953487)
# Win/lose count 11.5/0. Average score (18.442528735632184)
# Win/lose count 21.0/6.0. Average score (18.40340909090909)
# Win/lose count 23.5/3.0. Average score (18.426966292134832)
# Win/lose count 15.0/4.0. Average score (18.344444444444445)
# Win/lose count 18.5/2.0. Average score (18.324175824175825)
# Win/lose count 21.5/2.0. Average score (18.33695652173913)
# Win/lose count 18.0/0. Average score (18.333333333333332)
# Win/lose count 23.5/4.0. Average score (18.345744680851062)
# Win/lose count 22.5/1.0. Average score (18.378947368421052)
# Win/lose count 21.0/2.0. Average score (18.385416666666668)
# Win/lose count 21.0/1.0. Average score (18.4020618556701)
# Win/lose count 17.0/0. Average score (18.387755102040817)
# Win/lose count 21.5/1.0. Average score (18.40909090909091)
# Win/lose count 21.0/1.0. Average score (18.425)
# Final score: 18.425

# %%
agent_mimicker = Mimicker(n_state=3, n_action=4)
agent_mimicker.learn(demonstrations,epochs=100,batch_size=32,prefix='mimicker_train', viz=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 3, 3, 16)          448
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 1, 1, 16)          2320
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 16)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 2,836
# Trainable params: 2,836
# Non-trainable params: 0
# _________________________________________________________________
# Train on 16080 samples, validate on 4020 samples
# Epoch 1/100
# 16080/16080 [==============================] - 2s 155us/step - loss: 0.8896 - acc: 0.6139 - val_loss: 0.6878 - val_acc: 0.7226
# Epoch 2/100
# 16080/16080 [==============================] - 2s 131us/step - loss: 0.5748 - acc: 0.7693 - val_loss: 0.5229 - val_acc: 0.7818
# Epoch 3/100
# 16080/16080 [==============================] - 2s 134us/step - loss: 0.4509 - acc: 0.8297 - val_loss: 0.4212 - val_acc: 0.8368
# Epoch 4/100
# 16080/16080 [==============================] - 2s 132us/step - loss: 0.3729 - acc: 0.8631 - val_loss: 0.4000 - val_acc: 0.8316
# Epoch 5/100
# 16080/16080 [==============================] - 2s 133us/step - loss: 0.3253 - acc: 0.8817 - val_loss: 0.3449 - val_acc: 0.8649
# Epoch 6/100
# 16080/16080 [==============================] - 2s 141us/step - loss: 0.2987 - acc: 0.8883 - val_loss: 0.3177 - val_acc: 0.8729
# Epoch 7/100
# 16080/16080 [==============================] - 2s 134us/step - loss: 0.2750 - acc: 0.8999 - val_loss: 0.3197 - val_acc: 0.8701
# Epoch 8/100
# 16080/16080 [==============================] - 2s 136us/step - loss: 0.2668 - acc: 0.9007 - val_loss: 0.3323 - val_acc: 0.8488
# Epoch 9/100
# 16080/16080 [==============================] - 2s 135us/step - loss: 0.2482 - acc: 0.9095 - val_loss: 0.3055 - val_acc: 0.8577
# Epoch 10/100
# 16080/16080 [==============================] - 2s 148us/step - loss: 0.2376 - acc: 0.9119 - val_loss: 0.2940 - val_acc: 0.8769
# Epoch 11/100
# 16080/16080 [==============================] - 2s 135us/step - loss: 0.2299 - acc: 0.9142 - val_loss: 0.2905 - val_acc: 0.8836
# Epoch 12/100
# 16080/16080 [==============================] - 2s 133us/step - loss: 0.2171 - acc: 0.9224 - val_loss: 0.3107 - val_acc: 0.8818
# Epoch 13/100
# 16080/16080 [==============================] - 2s 135us/step - loss: 0.2119 - acc: 0.9225 - val_loss: 0.2910 - val_acc: 0.8704
# Epoch 14/100
# 16080/16080 [==============================] - 2s 142us/step - loss: 0.2042 - acc: 0.9257 - val_loss: 0.3008 - val_acc: 0.8624
# Epoch 15/100
# 16080/16080 [==============================] - 2s 139us/step - loss: 0.2000 - acc: 0.9248 - val_loss: 0.2793 - val_acc: 0.8876
# Epoch 16/100
# 16080/16080 [==============================] - 2s 137us/step - loss: 0.1940 - acc: 0.9290 - val_loss: 0.3078 - val_acc: 0.8739
# Epoch 17/100
# 16080/16080 [==============================] - 2s 138us/step - loss: 0.1894 - acc: 0.9285 - val_loss: 0.2710 - val_acc: 0.8831
# Epoch 18/100
# 16080/16080 [==============================] - 2s 140us/step - loss: 0.1826 - acc: 0.9321 - val_loss: 0.3069 - val_acc: 0.8769
# Epoch 19/100
# 16080/16080 [==============================] - 2s 135us/step - loss: 0.1810 - acc: 0.9317 - val_loss: 0.2874 - val_acc: 0.8836
# Epoch 20/100
# 16080/16080 [==============================] - 2s 135us/step - loss: 0.1773 - acc: 0.9338 - val_loss: 0.2748 - val_acc: 0.8843
# Epoch 21/100
# 16080/16080 [==============================] - 2s 138us/step - loss: 0.1730 - acc: 0.9368 - val_loss: 0.3234 - val_acc: 0.8719
# Epoch 22/100
# 16080/16080 [==============================] - 2s 136us/step - loss: 0.1716 - acc: 0.9352 - val_loss: 0.2833 - val_acc: 0.8828

# %%
# Evaluation

test(agent_mimicker,env,epochs_test,prefix='mimicker_test')
HTML(display_videos('mimicker_test1.mp4'))
# Out:
# Win/lose count 21.5/1.0. Average score (20.5)
# Win/lose count 24.0/2.0. Average score (21.25)
# Win/lose count 23.5/2.0. Average score (21.333333333333332)
# Win/lose count 16.0/2.0. Average score (19.5)
# Win/lose count 24.0/3.0. Average score (19.8)
# Win/lose count 7.0/0. Average score (17.666666666666668)
# Win/lose count 24.5/3.0. Average score (18.214285714285715)
# Win/lose count 24.5/3.0. Average score (18.625)
# Win/lose count 16.0/6.0. Average score (17.666666666666668)
# Win/lose count 27.0/1.0. Average score (18.5)
# Win/lose count 16.5/0. Average score (18.318181818181817)
# Win/lose count 13.0/1.0. Average score (17.791666666666668)
# Win/lose count 9.5/1.0. Average score (17.076923076923077)
# Win/lose count 27.5/2.0. Average score (17.678571428571427)
# Win/lose count 20.5/4.0. Average score (17.6)
# Win/lose count 21.0/3.0. Average score (17.625)
# Win/lose count 22.5/6.0. Average score (17.558823529411764)
# Win/lose count 28.0/3.0. Average score (17.97222222222222)
# Win/lose count 25.5/6.0. Average score (18.05263157894737)
# Win/lose count 25.0/5.0. Average score (18.15)
# Win/lose count 25.0/2.0. Average score (18.38095238095238)
# Win/lose count 22.0/3.0. Average score (18.40909090909091)
# Win/lose count 21.0/1.0. Average score (18.47826086956522)
# Win/lose count 20.0/0. Average score (18.541666666666668)
# Win/lose count 21.0/4.0. Average score (18.48)
# Win/lose count 20.0/4.0. Average score (18.384615384615383)
# Win/lose count 19.5/2.0. Average score (18.35185185185185)
# Win/lose count 28.0/2.0. Average score (18.625)
# Win/lose count 20.5/4.0. Average score (18.551724137931036)
# Win/lose count 16.0/6.0. Average score (18.266666666666666)
# Final score: 18.266666666666666
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Comparison performances

for temp in [0.1,0.3,0.5]:
    print("TEMPERATURE : ", str(temp))
    env = EnvironmentExploring(grid_size=size, max_time=T,temperature=temp)
    
    print('Test of the Mimicker Agent')
    test(agent_mimicker,env,epochs_test)
# Out:
# TEMPERATURE :  0.1
# Test of the Mimicker Agent
# Win/lose count 7.5/0. Average score (7.5)
# Win/lose count 9.0/1.0. Average score (7.75)
# Win/lose count 6.0/0. Average score (7.166666666666667)
# Win/lose count 14.5/1.0. Average score (8.75)
# Win/lose count 7.5/1.0. Average score (8.3)
# Win/lose count 6.0/0. Average score (7.916666666666667)
# Win/lose count 10.5/0. Average score (8.285714285714286)
# Win/lose count 8.0/0. Average score (8.25)
# Win/lose count 10.5/0. Average score (8.5)
# Win/lose count 8.5/2.0. Average score (8.3)
# Win/lose count 8.5/1.0. Average score (8.227272727272727)
# Win/lose count 13.0/1.0. Average score (8.541666666666666)
# Win/lose count 7.0/0. Average score (8.423076923076923)
# Win/lose count 8.0/0. Average score (8.392857142857142)
# Win/lose count 7.0/1.0. Average score (8.233333333333333)
# Win/lose count 4.0/2.0. Average score (7.84375)
# Win/lose count 5.0/0. Average score (7.676470588235294)
# Win/lose count 7.0/0. Average score (7.638888888888889)
# Win/lose count 5.5/0. Average score (7.526315789473684)
# Win/lose count 8.5/0. Average score (7.575)
# Win/lose count 9.0/1.0. Average score (7.595238095238095)
# Win/lose count 9.5/1.0. Average score (7.636363636363637)
# Win/lose count 6.5/0. Average score (7.586956521739131)
# Win/lose count 9.0/0. Average score (7.645833333333333)
# Win/lose count 7.0/0. Average score (7.62)
# Win/lose count 8.0/1.0. Average score (7.596153846153846)
# Win/lose count 8.0/1.0. Average score (7.574074074074074)
# Win/lose count 12.5/0. Average score (7.75)
# Win/lose count 10.0/0. Average score (7.827586206896552)
# Win/lose count 3.5/0. Average score (7.683333333333334)
# Final score: 7.683333333333334
# TEMPERATURE :  0.3
# Test of the Mimicker Agent
# Win/lose count 17.0/2.0. Average score (15.0)
# Win/lose count 26.0/3.0. Average score (19.0)
# Win/lose count 25.0/3.0. Average score (20.0)
# Win/lose count 23.0/2.0. Average score (20.25)
# Win/lose count 20.5/4.0. Average score (19.5)
# Win/lose count 23.0/1.0. Average score (19.916666666666668)
# Win/lose count 16.5/0. Average score (19.428571428571427)
# Win/lose count 24.0/3.0. Average score (19.625)
# Win/lose count 17.0/3.0. Average score (19.0)
# Win/lose count 19.0/1.0. Average score (18.9)
# Win/lose count 21.5/4.0. Average score (18.772727272727273)
# Win/lose count 6.0/0. Average score (17.708333333333332)
# Win/lose count 24.5/7.0. Average score (17.692307692307693)
# Win/lose count 22.0/1.0. Average score (17.928571428571427)
# Win/lose count 22.0/1.0. Average score (18.133333333333333)
# Win/lose count 20.0/0. Average score (18.25)
# Win/lose count 22.5/6.0. Average score (18.147058823529413)
# Win/lose count 19.0/2.0. Average score (18.083333333333332)
# Win/lose count 22.5/4.0. Average score (18.105263157894736)
# Win/lose count 24.0/1.0. Average score (18.35)
# Win/lose count 22.0/5.0. Average score (18.285714285714285)
# Win/lose count 24.5/3.0. Average score (18.431818181818183)
# Win/lose count 19.5/2.0. Average score (18.391304347826086)
# Win/lose count 22.0/4.0. Average score (18.375)
# Win/lose count 23.0/1.0. Average score (18.52)
# Win/lose count 22.0/3.0. Average score (18.53846153846154)
# Win/lose count 21.5/2.0. Average score (18.574074074074073)
# Win/lose count 18.0/2.0. Average score (18.482142857142858)
# Win/lose count 24.5/0. Average score (18.689655172413794)
# Win/lose count 25.5/3.0. Average score (18.816666666666666)
# Final score: 18.816666666666666
# TEMPERATURE :  0.5
# Test of the Mimicker Agent
# Win/lose count 40.0/4.0. Average score (36.0)
# Win/lose count 33.5/3.0. Average score (33.25)
# Win/lose count 5.0/0. Average score (23.833333333333332)
# Win/lose count 21.0/1.0. Average score (22.875)
# Win/lose count 22.0/5.0. Average score (21.7)
# Win/lose count 37.5/9.0. Average score (22.833333333333332)
# Win/lose count 37.5/2.0. Average score (24.642857142857142)
# Win/lose count 36.5/1.0. Average score (26.0)
# Win/lose count 38.0/5.0. Average score (26.77777777777778)
# Win/lose count 31.5/2.0. Average score (27.05)
# Win/lose count 29.5/1.0. Average score (27.181818181818183)
# Win/lose count 33.0/2.0. Average score (27.5)
# Win/lose count 32.0/2.0. Average score (27.692307692307693)
# Win/lose count 34.5/1.0. Average score (28.107142857142858)
# Win/lose count 29.0/3.0. Average score (27.966666666666665)
# Win/lose count 39.5/5.0. Average score (28.375)
# Win/lose count 37.0/2.0. Average score (28.764705882352942)
# Win/lose count 29.0/2.0. Average score (28.666666666666668)
# Win/lose count 22.5/3.0. Average score (28.18421052631579)
# Win/lose count 12.0/1.0. Average score (27.325)
# Win/lose count 40.5/8.0. Average score (27.571428571428573)
# Win/lose count 32.5/10.0. Average score (27.34090909090909)
# Win/lose count 37.5/2.0. Average score (27.695652173913043)
# Win/lose count 20.5/2.0. Average score (27.3125)
# Win/lose count 41.5/4.0. Average score (27.72)
# Win/lose count 40.5/5.0. Average score (28.01923076923077)
# Win/lose count 38.5/4.0. Average score (28.25925925925926)
# Win/lose count 39.0/5.0. Average score (28.464285714285715)
# Win/lose count 32.5/2.0. Average score (28.53448275862069)
# Win/lose count 38.5/3.0. Average score (28.766666666666666)
# Final score: 28.766666666666666
